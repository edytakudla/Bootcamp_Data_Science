# %% [markdown]
# # Rozkład jednostajny na odcinku $[a,b]$
# Gęstość zmiennej losowej $X$ o rozkładzie jednostajnym na odcinku $[a,b]$ jest dana przez
# $$
# \chi_{[a,b]}(x) = \left\{ \begin{array}{ll}
# \frac{1}{b-a} & \textrm{gdy}  x \in [a,b]\\
# 0 & \textrm{gdy } x \notin [a,b]
# \end{array} \right. ,
# $$
# gdzie $a<b$ oraz $a,b \in \mathbb{R}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# Definiujemy zmienną losową

# %%
t = np.arange(-5, 5, 0.05)
uniform=stats.uniform(-1,2)
print(uniform)

# %% [markdown]
# Narysujmy gęstość zmiennej losowej

# %%
# GĘSTOŚĆ - probability density function (pdf)
fig, ax = plt.subplots(1, 1)
plt.plot(t, uniform.pdf(t), 'ro-', ms=4, label='frozen pdf')
ax.set_xlim([-5,5])
ax.set_ylim([-0.1,1])
plt.legend()
plt.show()

# %% [markdown]
# Narysujmy dystrybuantę zmiennej losowej

# %%
# DYSTRYBUANRA - cdf
fig, ax = plt.subplots(1, 1)
ax.plot(t, uniform.cdf(t), 'b*-', ms=4, label='jednostajny cdf')
plt.legend()
plt.show()

# %% [markdown]
# Wylosujmy próbkę i narysujmy histogram na jednym obrazku

# %%
r = uniform.rvs(size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.5, label='histogram')
ax.legend(loc='best', frameon=False)
ax.plot(t, uniform.pdf(t), 'k-', lw=2, label='a=-1, b=1')
ax.set_xlim([-2,2])
ax.set_ylim([-0.1,0.7])
ax.legend()
plt.show()

# %% [markdown]
# Narysujmy gęstości rozkładu jednostajnego z różnymi parametrami

# %%
a_values = [1, 1, 1]
b_values = [1, 2, 3]
fig, ax = plt.subplots(1, 1)
for a, b in zip(a_values, b_values):
    dist = stats.uniform(a, b)
    plt.plot(t, dist.pdf(t), ls="--", c='black', label=r'$a=%1.f,\ b=%.1f$' % (a, a+b))
ax.set_xlim([-5,5])
ax.set_ylim([-0.1,1.1])    
plt.legend()
plt.show()

# %% [markdown]
# Narysujmy kilka histogramów różnych próbek z rozkładu jednostajnego o tych samych parametrach.

# %%
uniform=stats.uniform(0,1)
fig, ax = plt.subplots(nrows=5, ncols=5, figsize=(13, 13))

for i in np.arange(0,5):
    for j in np.arange(0,5):
        r = uniform.rvs(size=100)
        print('próba [',i, j, ']:', r[:5] )
        ax[i,j].hist(r, density=True)
plt.show()
# Out:
# próba [ 0 0 ]: [0.00522194 0.55986639 0.91132325 0.24027289 0.544553  ]
# próba [ 0 1 ]: [0.86450336 0.36935488 0.63693022 0.79615622 0.04076596]
# próba [ 0 2 ]: [0.41911495 0.30510062 0.0030957  0.70389753 0.90275619]
# próba [ 0 3 ]: [0.56991859 0.67800243 0.4700133  0.51170236 0.41985483]
# próba [ 0 4 ]: [0.4593555  0.1745082  0.57383555 0.33905042 0.2352033 ]
# próba [ 1 0 ]: [0.85656018 0.11202831 0.3783837  0.68464754 0.09099146]
# próba [ 1 1 ]: [0.08404548 0.62985729 0.10877955 0.88337116 0.30314165]
# próba [ 1 2 ]: [0.22440631 0.92614995 0.15260425 0.0791681  0.98868423]
# próba [ 1 3 ]: [0.5014494  0.12397773 0.15029559 0.79114975 0.97831064]
# próba [ 1 4 ]: [0.82015472 0.1573153  0.53217278 0.30125427 0.13036681]
# próba [ 2 0 ]: [0.69140638 0.46581722 0.29036538 0.56027996 0.87090397]
# próba [ 2 1 ]: [0.89653318 0.35765376 0.27820391 0.39978496 0.9104109 ]
# próba [ 2 2 ]: [0.42802148 0.82930024 0.6763869  0.432627   0.69026889]
# ...
