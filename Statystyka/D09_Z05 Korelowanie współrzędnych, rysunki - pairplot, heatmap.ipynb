# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować dane tak by 1. i 3. współrzędna były skorelowane a pozostałe nie.
# Proszę zwizualizować tą zależność za pomocą
#
# - sns.pairplot
# - sns.heatmap

# %% [markdown]
# Genereuje punkty:

# %%
n=1000
x1=stats.norm(0,1).rvs(n)
x2=stats.norm(0,1).rvs(n)
x4=stats.norm(0,1).rvs(n)
X=np.stack((x1,x2, 2*x1, x4 ),1)
#  trzecia zmienna zależy od pierwszej

# %% [markdown]
# Rysuje punkty jako pray współrzednych:

# %%
df=pd.DataFrame(X)
sns.pairplot(df, plot_kws=dict(s=10, edgecolor="k", linewidth=1))
plt.show()

# %% [markdown]
# Rysuję macierz korelacji za pomocą <tt>heatmap</tt>.

# %%
sns.set(style="darkgrid")
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
plt.show()

# %% [markdown]
# # Zadanie
# Wygeneruj dane 10. wymiarowe tak by
#
# - 1 3 5 współrzedna były skorelowane ze sobą
# - 7 8 współrzedna były skorelowane ze sobą
# - pozostałe były nieskorelowane

# %%
n=1000
x1=stats.norm(0,1).rvs(n)
x2=stats.norm(0,1).rvs(n)
x4=stats.norm(0,1).rvs(n)
x6=stats.norm(0,1).rvs(n)
x7=stats.norm(0,1).rvs(n)
x9=stats.norm(0,1).rvs(n)
x10=stats.norm(0,1).rvs(n)

X=np.stack((x1, x2, x1**2, x4, 3*x1+2, x6, x7, x7**3, x9, x10),1)

# %%
df=pd.DataFrame(X)
sns.pairplot(df, plot_kws=dict(s=10, edgecolor="k", linewidth=1))
plt.show()

# %%
sns.set(style="darkgrid")
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
plt.show()
# na heatmapie wykrywane są tylko korelacje liniowe!! brak korelacji na heatmapie nie oznacza braku korelacji w ogóle!!
