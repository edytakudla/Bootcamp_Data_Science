# %% [markdown]
# # Ile powinna firma zapłacić za set umiejętności w danym mieście -
#
# ## rozdział 2 - DS

# %%
import pandas as pd

# %%
df_offers = pd.read_csv("offers3.csv")

# %%
df_offers.shape
# Out:
# (1021, 1313)

# %%
df_info = df_offers[["company", "emp_type", "exp_lvl", "title", "salary_min", "salary_max", "city"]]
df_info
# Out:
#                             company   emp_type  exp_lvl  \
# 0               GTS Tech Sp. z o.o.  Permanent        3
# 1                      Mindbox S.A.        B2B        2
# 2                          BlueSoft        B2B        2
# 3                    Euro Bank S.A.  Permanent        2
# 4                           Addepto        B2B        2
# 5                      Mindbox S.A.        B2B        2
# 6                           Showpad        B2B        3
# 7                       itcruitment        B2B        3
# 8                             Margo        B2B        3
# 9                         Monterail        B2B        2
# 10                     Lemon Orange  Permanent        2
# 11                         Extradom        B2B        3
# 12                        Naturaily        B2B        2
# 13                   INTITEK Polska        B2B        2
# 14                       UPC Polska  Permanent        2
# 15                      itcruitment  Permanent        2
# 16           X-Coding IT Studio s.c        B2B        1
# 17                   Gorilla Agency        B2B        2
# 18                   INTITEK Polska        B2B        2
# 19    Novomatic Technologies Poland  Permanent        2
# 20                   INTITEK Polska        B2B        2
# 21    NOVOMATIC TECHNOLOGIES POLAND  Permanent        2
# 22    Novomatic Technologies Poland  Permanent        2
# 23         BLUE SERVICES SP. Z O.O.        B2B        3
# 24       NetworkedAssets Sp. z o.o.  Permanent        2
# 25                Reef Technologies        B2B        3
# 26              Statscore sp.z o.o.  Permanent        2
# 27              Statscore sp.z o.o.  Permanent        2
# 28                          Addepto        B2B        2
# 29                            zoovu        B2B        3
# ...                             ...        ...      ...
# 991                       SdNcenter        B2B        2
# 992                       Apollogic        B2B        1
# 993        GOGOmedia Software House        B2B        2
# 994                          Ladder        B2B        3
# 995                          Ladder        B2B        3
# 996            Macopedia Sp. z o.o.        B2B        2
# 997                     Globe Group        B2B        2
# 998                         itCraft        B2B        3
# 999                          BitBag        B2B        3
# 1000                Owls Department        B2B        1
# 1001                    Future Mind        B2B        3
# 1002                    Future Mind        B2B        2
# 1003          Schibsted Tech Polska  Permanent        2
# 1004                          Empik  Permanent        2
# 1005                     Netcompany  Permanent        3
# 1006                      Dynatrace  Permanent        3
# 1007                      Dynatrace  Permanent        3
# 1008                      Dynatrace  Permanent        3
# 1009             StepStone Services  Permanent        2
# 1010             Relyon IT Services        B2B        3
# 1011                     Netcompany  Permanent        2
# 1012                     Netcompany  Permanent        1
# 1013                     Netcompany  Permanent        2
# 1014             Relyon IT Services        B2B        2
# 1015         Web Solutions Workshop        B2B        2
# 1016             Relyon IT Services        B2B        3
# 1017                 NBC Sp. z o.o.        B2B        3
# 1018             Relyon IT Services        B2B        2
# 1019      Change of Scandinavia SSC  Permanent        2
# 1020                 NBC Sp. z o.o.        B2B        2
#
#                                          title  salary_min  salary_max  \
# 0     Senior Full-Stack Developer- Team Leader      6300.0     11200.0
# 1                       QA Automation Engineer     12000.0     20000.0
# 2                             Python Developer     10000.0     17500.0
# 3                                Developer RPA      3500.0      7000.0
# 4                                Data Engineer      8000.0     16000.0
# 5                       QA Automation Engineer     11000.0     14000.0
# 6                     Senior Frontend Engineer     13000.0     20000.0
# 7                DevOps Specialist - Architect     14000.0     20000.0
# 8                       UI Developer (Angular)     18000.0     21000.0
# 9                              Project Manager      6500.0      9700.0
# 10                 Angular Front-end Developer      4900.0      7000.0
# 11                   Senior Frontend Developer     13000.0     16000.0
# 12                             React Developer      6000.0     12000.0
# 13                          React.js Developer     10000.0     18000.0
# 14           Senior Software Developer Backend      5600.0      9100.0
# 15                  Embedded Software Engineer      7000.0      9800.0
# 16                   Junior IT Project Manager      4000.0      4500.0
# 17                             React Developer      6000.0     10000.0
# 18                  Test Automation Specialist     11000.0     16000.0
# 19              Java/OpenGL Software Developer      5250.0     10500.0
# 20                           Node.js Developer     10000.0     18000.0
# 21                             DevOps Engineer      5250.0     10500.0
# 22                Fullstack Software Developer      5250.0     10500.0
# 23                         AngularJS Developer      8000.0     14000.0
# 24                       Java/Kotlin Developer      5600.0      9100.0
# 25                     Senior Python Developer     13680.0     19950.0
# 26                               PHP Developer      4200.0      8050.0
# 27                              Node Developer      4200.0      8050.0
# 28     Machine Learning/Deep Learning Engineer     10000.0     20000.0
# 29                 Senior Full-Stack Developer     12000.0     18000.0
# ...                                        ...         ...         ...
# 991                 React Full Stack Developer     10000.0     20000.0
# 992                       Junior BI Consultant      3000.0      5000.0
# 993                              PHP Developer      6000.0     10000.0
# 994                          Node.js Developer     10000.0     17000.0
# 995                                QA Engineer      8000.0     13000.0
# 996                        Front-end Developer      7000.0     11000.0
# 997           Front-end Developer with Angular      7000.0      9000.0
# 998                        Front-end developer      8000.0     13000.0
# 999                    PHP (Symfony) Developer      9000.0     11000.0
# 1000                           Project Manager      4000.0      4500.0
# 1001                      Senior iOS Developer     11000.0     15000.0
# 1002                   Python/Django Developer      9000.0     12000.0
# 1003            Javascript Fullstack Developer      7000.0      9800.0
# 1004         JavaScript Developer - Empik Foto      5600.0      8400.0
# 1005                     Senior .NET Developer      9800.0     11900.0
# 1006  Java Software Engineer-SaaS/Managed Team      8400.0     15400.0
# 1007  Java Software Engineer-CloudControl Team      8400.0     15400.0
# 1008                     Senior Java Developer      8400.0     15400.0
# 1009                           DevOps Engineer      6300.0     11200.0
# 1010                  Lead Front-end Developer     16000.0     17600.0
# 1011                 MS Dynamics CRM Developer      5600.0      9800.0
# 1012            MS Dynamics Navision Developer      5600.0      9800.0
# 1013                            Java Developer      5600.0      9800.0
# 1014                Embedded Software Engineer     17000.0     19000.0
# 1015                       Mid-Level Developer      8000.0     11000.0
# 1016                       Native C# Developer     23000.0     28560.0
# 1017                     Tester Automatyzujący     10000.0     16800.0
# 1018                           Software Tester     10000.0     14000.0
# 1019            Dynamics AX Finance Consultant      7700.0     14000.0
# 1020                            Java Developer     15000.0     19000.0
#
#            city
# 0        Kraków
# 1        Kraków
# 2      Warszawa
# 3       Wrocław
# 4      Warszawa
# 5      Warszawa
# 6       Wrocław
# 7      Warszawa
# 8       Wrocław
# 9       Wrocław
# 10      Chorzów
# 11      Wrocław
# 12      Wrocław
# 13       Gdańsk
# 14     Katowice
# 15      Wrocław
# 16      Wrocław
# 17     Warszawa
# 18       Gdańsk
# 19       Kraków
# 20       Gdańsk
# 21       Kraków
# 22       Kraków
# 23        Sopot
# 24      Wrocław
# 25     Warszawa
# 26     Katowice
# 27     Katowice
# 28     Warszawa
# 29      Wrocław
# ...         ...
# 991    Warszawa
# 992      Poznań
# 993    Warszawa
# 994     Wrocław
# 995     Wrocław
# 996      Poznań
# 997      Poznań
# 998   Bydgoszcz
# 999       Opole
# 1000     Kraków
# 1001   Warszawa
# 1002   Warszawa
# 1003     Kraków
# 1004   Warszawa
# 1005   Warszawa
# 1006     Gdańsk
# 1007     Gdańsk
# 1008     Gdańsk
# 1009   Warszawa
# 1010    Wrocław
# 1011   Warszawa
# 1012   Warszawa
# 1013   Warszawa
# 1014   Katowice
# 1015     Poznań
# 1016   Warszawa
# 1017      Sopot
# 1018    Wrocław
# 1019       Łódź
# 1020  Zabierzów
#
# [1021 rows x 7 columns]

# %%
import re

columns = sorted(df_offers.columns.tolist())
str = " ".join(columns).upper()
str = re.sub('[0-9\-,.:\/\(\)\'\"]', ' ', str)

new_list = [x for x in str.split(" ") if len(x) >= 2]
ue = set(new_list)
len(ue)
# Out:
# 1123

# %%
1123 / 8
# Out:
# 140.375

# %%
numerek = 8
# sorted(ue)[(numerek-1)*141:numerek*141]

# %%
# list( sorted(set( filter(lambda x: x is not None, tg.values()) ) ))

# %%
dict6 = {'#C' : "C#",
 'AAS': None,
 'ABSTRACT' : None,
 'ACF' : None,
 'ACTIVE' : "ACTIVEDIRECTORY",
 'ADMINISTRACJA': "ADMINISTRACJA",
 'ADMINISTRATION': "ADMINISTRACJA",
 'ADOBE' : None,
 'ADV' : None,
 'ADVANCED': None,
 'ADWORDS' : "ADWORDS",
 'AESTHETIC': None,
 'AFTER': None,
 'AGILE' : "Agile",
 'AI' : "AI",
 'AIRFLOW' : "AIRFLOW",
 'AKKA' : "AKKA",
 'ALGORITHMS' : 'ALGORITHMS',
 'ALM' : None,
 'AMAZON' : "AWS",
 'AMINISTRACJA' : "ADMINISTRACJA",
 'AMQP' : "ACTIVEMQ",
 'ANALITICAL' : None,
'ANALITYCZNE' : None,
'ANALYSIS' : None,
'ANALYST' : None,
'ANALYSTICS': None,
'ANALYTICS' : None,
'ANALYZER' : None,
'AND' : None,
'ANDROID' : "ANDROID",
'ANGIELSKI': "ENGLISH",
'ANGIELSKIEGO': "ENGLISH",
'ANGULAR' :"ANGULARJS",
'ANGULARJS' : "ANGULARJS",
'ANIMATIONS': None,
'ANSIBLE': "ANSIBLE",
'ANT':"ANT",
'ANY':None,
'APACHE':None,
'APEX':'APEX',
'API':None,
'APIS':None,
'APLIKACJI':None,
'APP':None,
'APPCODE' : "APPCODE",
'APPIUM': "APPIUM",
'APPLICATIONS':None,
'APPROACH':None,
'APPS':None,
'AR':None,
'ARCHITECTURE':"ARCHITECTURE",
'ARCHITEKT':"ARCHITECTURE",
'ARM':"ARM",
'ARP':None,
'ARTIFACTORY' : 'ARTIFACTORY',
'AS':None,
'ASP' : "ASP",
'ASPICE' : None,
'ASSURANCE' : None,
'ASYNC' : None,
'ATTITUDE' : None,
'AUTOFAC' : None,
'AUTOMATED':None,
'AUTOMATING':None,
'AUTOMATION':None,
'AUTOMATYCZNYCH':None,
'AUTOMOTIVE':None,
'AUTOSAR':None,
'AVAILABILITY':None,
 'PLANING':'PLANNING',
 'PLATFORM':None,
 'PLATFORMS':None,
 'PLAYER':None,
 'PLIKOWE':None,
 'PLUGIN':None,
 'PM':'PROJECT MANAGEMENT',
 'PMBOK':'PROJECT MANAGEMENT',
 'POI':None,
 'POINT':None,
 'POKREWNE':None,
 'POLISH':'POLISH',
 'POPRAWA':None,
 'POSIX':'POSIX',
 'POSTGRES':'POSTGRESQL',
 'POSTGRESQL':'POSTGRESQL',
 'POSTMAN':'POSTMAN',
 'POSTRESQL':'POSTGRESQL',
 'POWER':None,
 'POWERSHELL':'POWERSHELL',
 'POZIOMIE':None,
 'PRACTICES':None,
 'PRACY':None,
 'PREFEROWANE':None,
 'PREPARTATION':None,
 'PREPROCESSORS':None,
 'PRESSURE':None,
 'PRESTASHOP':'PRESTASHOP',
 'PREVIOUS':None,
 'PRIMEFACES':'PRIMEFACES',
 'PRINCE':'PRINCE2',
 'PRINCIPLES':None,
 'PRO':None,
 'PROACTIVITY':None,
 'PROBLEM':None,
 'PROCEDURE':None,
 'PROCESS':None,
 'PROCESSING':None,
 'PRODUCT':None,
 'PRODUCTS':None,
 'PROGRAMING':'PROGRAMMING',
 'PROGRAMMING':'PROGRAMMING',
 'PROGRAMOWANIU':'PROGRAMMING',
 'PROJECT':None,
 'PROJECTS':None,
 'PROJEKTAMI':None,
 'PROJEKTOWANIE':None,
 'PROJEKTOWYCH':None,
 'PROMETHEUS':'PROMETHEUS',
 'PROMISE':None,
 'PROTOCOL':'PROTOCOLS',
 'PROTOCOLS':'PROTOCOLS',
 'PROTOTYPEJS':'PROTOTYPING',
 'PROTOTYPING':'PROTOTYPING',
 'PROTRACTOR':'PROTRACTOR',
 'PS':'PHOTOSHOP',
 'PSM':'PSM',
 'PSR':'PSR',
 'PTES':'PTES',
 'PUPPET':'PUPPET',
 'PWA':'PWA',
 'PYHTON':'PYTHON',
 'PYRAMID':'PYRAMID',
 'PYTH':'PYTHON',
 'PYTHON':'PYTHON',
 'PYTORCH':'PYTORCH',
 'QA':'QA',
 'QLICKVIEW':'QLIKVIEW',
 'QML':'QML',
 'QT':'QT',
 'QTEST':'QTEST',
 'QTP':'QTP',
 'QUALITY':None,
 'QUICK':None,
 'RABBITMQ':'RABBITMQ',
 'RAILS':'RUBY ON RAILS',
 'RDBMS':'RDBMS',
 'REACT':'REACTJS',
 'REACT&REDUX':'REACTJS',
 'REACTJS':'REACTJS',
 'REACTRXJS':'REACTJS',
 'READINESS':None,
 'REALITY':None,
 'RECEIVABLE':None,
 'RECOVERY':None,
 'RED':None,
 'REDHAT':'REDHAT',
 'REDIS':'REDIS',
 'REDPRAIRIE':'REDPRAIRIE',
 'REDUCE':None,
 'REDUX':'REDUX',
 'REGISTRY':None,
 'REGRESSION':None,
 'RELACYJNE':None,
 'RELATIONAL':'SQL',
 'RELIABILITY':None,
 'REMOTE':None,
 'REPORT':None,
 'REPORTING':'REPORTING',
 'REPORTS':'REPORTING',
 'REQUIREMENTS':None,
 'RESEARCH':'RESEARCH',
 'RESPONSE':None,
 'RESPONSIVE':None,
 'REST':'REST',
 'RESTFUL':'REST',
 'RETROFIT':'RETROFIT',
 'REVIEW':None,
 'REVIEWS':None,
 'ROBOT':'ROBOT',
 'ROLE':None,
 'ROOM':None,
 'ROR':None,
 'ROSYJSKI':'RUSSIAN',
 'ROUTING':'ROUTING',
 'ROZWIĄZAŃ':None,
 'RPA':'RPA',
 'RSPEC':'RSPEC',
 'RTOS':'RTOS',
 'RUBY':'RUBYONRAILS',
 'RUNNING':None,
 'RWD':'RWD',
 'RX':'RX',
 'RXCOCOA':'RXCOCOA',
 'RXJAVA':'RX',
 'RXJS':'RX',
 'RXKOTLIN':'RX',
 'RXSWIFT':'RX',
 'SAAS':'SAAS',
 'SAFE':None,
 'SALARY_MAX':None,
 'SALARY_MIN':None,
 'SALESFORCE':'SALESFORCE',
 'SAMLV':'SAMLV',
 'SAOP':'SAOP',
 'SAP':'SAP',
 'SASS':'SAAS',
 'SAST':'SAST',
 'SCALA':'SCALA',
 'SCALABILITY':None,
 'SCENARIOS':None,
 'IMPALA': 'IMPALA',
 'IN': None,
 'INBOUND': None,
 'INCIDENT': None,
 'INDUSTRY': None,
 'INFLUXDB': 'INFLUXDB',
 'INFORMATYCZNE': None,
 'INFRASTRUKTURY': None,
 'INJECTION': None,
 'INNYCH': None,
 'INTEGRACYJNYCH': None,
 'INTEGRATION': None,
 'INTELLIGENCE': 'MACHINELEARNING',
 'INTELLIJ': 'INTELLIJ',
 'INTERACTION': None,
 'INTERFEJSY': None,
 'INTERFEJSÓW': None,
 'INTERNALS': None,
 'INVENTORY': None,
 'INVISION': 'INVISION',
 'IO': None,
 'IONIC': 'IONIC',
 'IOS': 'IOS',
 'IOT': 'IOT',
 'IP': 'IP',
 'IPC': None,
 'IPV': None,
 'ISO': 'ISO',
 'ISOMORPHIC': 'ISOMORPHIC',
 'ISTGB': 'ISTQB',
 'ISTQB': 'ISTQB',
 'IT': None,
 'ITIL': 'ITIL',
 'IVR': 'IVR',
 'JAMF': 'JAMF',
 'JASIMINE': 'JASMINE',
 'JASMIN': 'JASMINE',
 'JASMINE': 'JASMINE',
 'JASPER': 'JASPER',
 'JAVA': 'JAVA',
 'JAVASCRIP': 'JAVASCRIPT',
 'JAVASCRIPT': 'JAVASCRIPT',
 'JBEHAVE': 'JBEHAVE',
 'JBOSS': 'JBOSS',
 'JCR': 'JCR',
 'JEE': 'JAVA',
 'JENINKS': 'JENKINS',
 'JENKINS': 'JENKINS',
 'JENKIS': 'JENKINS',
 'JEST': 'JEST',
 'JETTY': 'JETTY',
 'JIRA': 'JIRA',
 'JLINK': 'JLINK',
 'JM': 'JMETER',
 'JMETER': 'JMETER',
 'JPA': 'JAVA',
 'JQUERRY': 'JQUERY',
 'JQUERY': 'JQUERY',
 'JS': 'JAVASCRIPT',
 'JSF': 'JAVA',
 'JSON': 'JSON',
 'JUNIT': 'JUNIT',
 'JVM': 'JVM',
 'JWT': 'JASON',
 'JĘZYK': None,
 'JĘZYKA': None,
 'KAFKA': 'KAFKA',
 'KANBAN': 'KANBAN',
 'KARAF': 'KARAF',
 'KARMA': 'KARMA',
 'KATALON': 'KATALON',
 'KERAS': 'KERAS',
 'KERBEROS': 'KERBEROS',
 'KIERUNKI': None,
 'KIF': None,
 'KNOCKOUT': 'KNOCKOUT',
 'KNOWLEDGE': None,
 'KOMPUTERÓW': None,
 'KOMUNIKACYJNE': None,
 'KOMUNIKATYWNYM': None,
 'KORPORACYJNA': None,
 'KOTLIN': 'KOTLIN',
 'KREATYWNOŚĆ': None,
 'KUBERNATES': 'KUBERNETES',
 'KUBERNE': 'KUBERNETES',
 'KUBERNETES': 'KUBERNETES',
 'KVM': 'KVM',
 'LAKE': None,
 'LANGUAGE': None,
 'LANGUAGES': None,
 'LARAVEL': 'LARAVEL',
 'LARGE': None,
 'LAYOUT': None,
 'LDAP': 'LDAP',
 'LEADERSHIP': 'LEADERSHIP',
 'LEADING': 'LEADERSHIP',
 'LEAN': 'LEAN',
 'LEARNING': 'LEARNING',
 'LESS': 'LESS',
 'LIBGDX': 'LIBGDX',
 'LIBVIRT': 'LIBVIRT',
 'LIFECYCLE': None,
 'LIFERAY': 'LIFERAY',
 'LIGHTNING': None,
 'LINE': None,
 'LINQ': 'LINQ',
 'LINUX': 'LINUX',
 'LO': None,
 'LOGIC': None,
 'LOGICAL': None,
 'LOKALNEJ': None,
 'LOW': None,
 'LUB': None,
 'LUCENE': 'LUCENE',
 'LUMIRA': 'LUMIRA',
 'LWJGL': 'LWJGL',
 'MACHINE': 'MACHINELEARNING',
 'MAGENTO': 'MAGENTO',
 'MAKING': None,
 'MANAGAMENT': 'MANAGEMENT',
 'MANAGEMENT': 'MANAGEMENT',
 'MANAGER': 'MANAGEMENT',
 'MANAGING': 'MANAGEMENT',
 'MANAGMENT': 'MANAGEMENT',
 'MANUAL': None,
 'MAP': None,
 'MARATHON': None,
 'MARIADB': 'MARIADB',
 'MARKET': None,
 'MARKUP': 'MARKUP',
 'MASONRY': 'MASONRY',
 'MASTER': None,
 'MATERIAL': None,
 'MATHS': 'MATHS',
 'MAVEN': 'MAVEN',
 'MAVN': 'MAVEN',
 'MDM': 'MDM',
 'MEDICAL': None,
 'MEMCACHE': 'MEMCACHE',
 'MEMCACHED': 'MEMCACHE',
 'MENAGMENT': 'MANAGEMENT',
 'CALL' : None,
 'CAMEL' : 'CAMEL',
 'CAMERA' : None,
 'CAMUNDA' : 'CAMUNDA',
 'CANVAS' : 'CANVAS',
 'CARTHAGE' : 'CARTHAGE',
 'CASE' : None,
 'CASES' : None,
 'CASSANDRA' : 'CASSANDRA',
 'CC' : 'CC',
 'CCNA' : 'CC',
 'CCNP' : 'CC',
 'CCS' : 'CC',
 'CCTV' : 'CC',
 'CD' : None,
 'CELERY' : 'CELERY',
 'CENTER' : None,
 'CENTOS' : 'CENTOS',
 'CERTIFICATE' : None,
 'CERTIFIED' : None,
 'CHAI' : 'CHAI',
 'CHANGE' : None,
 'CHEF' : None,
 'CHROME' : 'CHROME',
 'CI' : 'CI',
 'CITY' : None,
 'CLEAN' : None,
 'CLI' : None,
 'CLIENT' : None,
 'CLOJURE' : 'CLOJURE',
 'CLOUD' : 'CLOUD',
 'CLOUDNATIVE' : 'CLOUD',
 'CMAKE' : 'CMAKE',
 'CMS' : 'CMS',
 'CO' : 'CO',
 'COCOA' : 'CO',
 'COCOAPODS' : 'CO',
 'CODE' : None,
 'CODING' : None,
 'COFFEESCRIPT' : 'COFFEESCRIPT',
 'COMMAND' : None,
 'COMMERCE' : 'E-COMMERCE',
 'COMMITMENT' : None,
 'COMMU' : None,
 'COMMUNICATION' : None,
 'COMMUNICATIONS' : None,
 'COMPANY' : None,
 'COMPASS' : 'COMPASS',
 'COMPOSE' : 'COMPOSER',
 'COMPOSER' : 'COMPOSER',
 'COMPTIA' : 'COMPTIA',
 'COMPUTER' : None,
 'COMPUTING' : None,
 'CONCEPTS' : None,
 'CONCRETE' : None,
 'CONFLICTS' : None,
 'CONFLUENCE' : None,
 'CONNECT' : 'CONNECT',
 'CONSUL' : 'CONSUL',
 'CONTACT' : None,
 'CONTAINER' : 'CONTAINER',
 'CONTAINERS' : 'CONTAINER',
 'CONTINOUS' : None,
 'CONTINUOUS' : None,
 'CONTRACTS' : None,
 'CONTROL' : None,
 'CORDOVA' : 'CORDOVA',
 'CORE' : None,
 'COUNT' : None,
 'CRAFT' : 'CRAFT',
 'CREATING' : None,
 'CREATION' : None,
 'CREATIVE' : None,
 'CRITICAL' : None,
 'CRM' : 'CRM',
 'CROSS' : None,
 'CRYPTOGRAPHIC' : 'CRYPTOGRAPHY',
 'CRYPTOGRAPHY': 'CRYPTOGRAPHY',
 'CSS' : 'CSS',
 'CUCUMBER' : 'CUCUMBER',
 'CURL' : None,
 'CUSTOMER' : None,
 'CXF' : 'CXF',
 'CYBERSECURITY' : 'CYBERSECURITY',
 'CYPRESS' : 'CYBERSECURITY',
 'DAGGER' : 'DAGGER',
 'DANYCH' : None,
 'DAO' : 'DATAACCESSOBJECT',
 'DAST' : 'DYNAMICAPPLICATIONSECURITYTESTING',
 'DATA' : None,
 'DATABASE' : 'DATABASES',
 'DATABASES' : 'DATABASES',
 'DATADOG' : 'DATADOG',
 'DAX' : 'DAX',
 'DB' : 'DATABASES',
 'DDD' : 'DATADRIVENDEVELOPMENT',
 'DEBIAN' : 'DEBIAN',
 'DEBUGGING' : None,
 'DECISION' : None,
 'DEEP' : 'DEEPLEARNING',
 'DEFINING' : None,
 'DEGREE' : None,
 'DELEGATION' : None,
 'DELIVERIES' : None,
 'DELIVERY' : None,
 'DEPENDENCY' : None,
 'DEPLOYMENT' : None,
 'DESIGN' : 'DESIGNING',
 'DESIGNING' : 'DESIGNING',
 'DESK' : None,
 'DETAIL' : None,
 'DEV' : 'DEVELOPMENT',
 'DEVELOPER' : 'DEVELOPMENT',
 'DEVELOPING' : 'DEVELOPMENT',
 'DEVELOPMENT' : 'DEVELOPMENT',
 'DEVICE' : None,
 'DEVICES' : None,
 'DEVOPS' : 'DEVOPS',
 'DHCP' : 'DHCP',
 'DIGITAL' : None,
 'DIRECT' : None,
 'DIRECTORY' : 'ACTIVEDIRECTORY',
 'DIRECTX' : 'DIRECTX',
 'DISTRIBUTED' : None,
 'DJANGO' : 'DJANGO',
 'DLANGO' : 'DJANGO',
 'DLT' : 'DLT',
 'DNS' : 'DNS',
 'DOCKE' : 'DOCKER',
 'DOCKER' : 'DOCKER',
 'DOCTRINE' : None,
 'DOKUMENTACJA' : None,
 'DOŚWIADCZENIE' : None,
 'DRF' : 'DRF',
 'DRIVER' : None,
 'DRUPAL' : 'DRUPAL',
 'DSC' : 'DSC',
 'DSDM' : 'DSDM',
 'DSP' : 'DSP',
 'DWH' : 'DWH',
 'DYNAMICS': 'CRM',
  'NUXT':'NUXTJS',
  'OBJECT':'OBJECT',
 'OBJECTIVE':'OBJECT',
 'ODATA':'ODATA',
 'ODOO':'ODOO',
 'OF':None,
 'OFFICE':'OFFICE',
 'OLTP':'OLTP',
 'ON':None,
 'ONOS':None,
 'OOP':'OBJECT',
 'OPEN':None,
 'OPENCV':'OPENCV',
 'OPENFL':'OPENFL',
 'OPENGL':'OPENGL',
 'OPENJPA':'OPENJPA',
 'OPENSHIFT':'OPENSHIFT',
 'OPENSTACK':'OPENSTACK',
 'OPERATIONS':None,
 'OPSGENIE':'OPSGENIE',
 'OPTIMIZATION':None,
 'OR':None,
 'ORACLE':'ORACLE',
 'ORAZ':None,
 'ORDER':None,
 'ORGANISATION':None,
 'ORGANIZATION':None,
 'ORIENTED':None,
 'ORM':'ORM',
 'OS':'OS',
 'OSOBISTYCH':None,
 'OSS':'OSS',
 'OTHER':None,
 'OTRS':'OTRS',
 'OUTBOUND':None,
 'OVIRT':'OVIRT',
 'OWASP':'OWASP',
 'OWNERSHIP':None,
 'PACKER':'None',
 'PANDAS':'PANDAS',
 'PASSION':None,
 'PATIENCE':None,
 'PATTERNS':None,
 'PATTERS':None,
 'PAYABLE':None,
 'PBX':'PBX',
 'PENTAHO':'PENTAHO',
 'PENTESTING':'PENTESTING',
 'PEOPLE':None,
 'PEP':None,
 'PERFORMANCE':None,
 'PERL':'PERL',
 'PERSISTENCE':None,
 'PHASER':'PHASER',
 'PHOTON':None,
 'PHOTOSHOP':'PHOTOSHOP',
 'PHP':'PHP',
 'PHPUNIT':'PHP',
 'PIG':None,
 'PIPELINE':None,
 'PIXIJS':'PIXIJS',
 'PIŚMIE':None,
 'PL':None,
 'PLAN':None,
 'PLANET':'PLANET',
 'PLANING':None,
 'PLATFORM':None,
 'PLATFORMS':None,
 'PLAYER':None,
 'PLIKOWE':None,
 'PLUGIN':None,
 'PM':'PROJECT MANAGER',
 'PMBOK':'PROJECT MANAGER',
 'POI':None,
 'POINT':None,
 'POKREWNE':None,
 'POLISH':'POLISH',
 'POPRAWA':None,
 'POSIX':'POSIX',
 'POSTGRES':'POSTGRESQL',
 'POSTGRESQL':'POSTGRESQL',
 'POSTMAN':'POSTMAN',
 'POSTRESQL':'POSTGRESQL',
 'POWER':'POWERSHELL',
 'POWERSHELL':'POWERSHELL',
 'POZIOMIE':None,
 'PRACTICES':None,
 'PRACY':None,
 'PREFEROWANE':None,
 'PREPARTATION':None,
 'PREPROCESSORS':None,
 'PRESSURE':None,
 'PRESTASHOP':'PRESTASHOP',
 'PREVIOUS':None,
 'PRIMEFACES':'PRIMEFACES',
 'PRINCE':None,
 'PRINCIPLES':None,
 'PRO':None,
 'PROACTIVITY':None,
 'PROBLEM':None,
 'PROCEDURE':None,
 'PROCESS':None,
 'PROCESSING':None,
 'PRODUCT':None,
 'PRODUCTS':None,
 'PROGRAMING':None,
 'PROGRAMMING':None,
 'PROGRAMOWANIU':None,
 'PROJECT':None,
 'PROJECTS':None,
 'PROJEKTAMI':None,
 'PROJEKTOWANIE':None,
 'PROJEKTOWYCH':None,
 'PROMETHEUS':'PROMETHEUS',
 'PROMISE':'PROMISE',
 'PROTOCOL':None,
 'PROTOCOLS':None,
 'PROTOTYPEJS':'PROTOTYPEJS',
 'PROTOTYPING':None,
 'PROTRACTOR':'PROTRACTOR',
 'PS':'PLAY STATION',
 'PSM':None,
 'PSR':None,
 'PTES':'PENTESTS',
 'PUPPET':'PUPPET',
 'PWA':'PWA',
 'PYHTON':'PYTHON',
 'PYRAMID':None,
 'PYTH':'PYTHON',
 'PYTHON':'PYTHON',
 'PYTORCH':'MACHNELEARNING',
 'QA':'QUALITYASSURANCE',
 'QLICKVIEW':'QUICKVIEW',
 'QML':'QML',
 'QT':'QT',
 'QTEST':'QUALITYASSURANCE',
 'QTP':'QTP',
 'QUALITY':'QUALITYASSURANCE',
 'QUICK':'QUICKVIEW',
 'RABBITMQ':'RABBITMQ',
 'RAILS':'RUBY',
 'RDBMS':'RDBMS',
 'REACT':'REACTJS',
 'REACT&REDUX':'REACTJS',
 'REACTJS':'REACTJS',
 'REACTRXJS':'REACTJS',
 'READINESS':None,
 'REALITY':None,
 'RECEIVABLE':None,
'RECOVERY':None,
 'RED':'REDHAT',
 'REDHAT':'REDHAT',
 'REDIS':'REDIS',
 'REDPRAIRIE':'REDPRAIRIE',
 'REDUCE':None,
 'REDUX':None,
 'REGISTRY':None,
 'REGRESSION':'MACHNELEARNING',
 'RELACYJNE':None,
 'RELATIONAL':None,
  'EARLGREY': 'EARLGREY',
 'ECCOMERCE': 'E-COMMERCE',
 'ECLIPSE': 'ECLIPSE',
 'ECMASCRIPT': 'JAVASCRIPT',
 'ECOMMERCE': 'E-COMMERCE',
 'EDI': 'EDI',
 'EE': None,
 'EIP': None,
 'EIXIR': 'ELIXIR',
 'EJB': 'EJB',
 'ELASTIC': 'ELASTICSEARCH',
 'ELASTICSEARCH': 'ELASTICSEARCH',
 'ELECTRON': None,
 'ELEMENTS': None,
 'ELIXIR': 'ELIXIR',
 'ELK': None,
 'ELT': None,
 'EMBEDDED': 'EMBEDDED',
 'EMBER': 'EMBER.JS',
 'EMPATHY': 'EMPATHY',
 'EMP_TYPE': None,
 'END': None,
 'ENERGY': None,
 'ENGINE': None,
 'ENGLISH': 'ENGLISH',
 'ENTERPRISE': None,
 'ENTITI': 'ENTITYFRAMEWORK',
 'ENTITY': 'ENTITYFRAMEWORK',
 'ENVIRONMENT': None,
 'ERP': None,
 'ES': 'JAVASCRIPT',
 'ESB': 'ENTERPRISESERVICEBUS',
 'ESNEXT': 'JAVASCRIPT',
 'ESPRESSO': 'ESPRESSO',
 'ETC': None,
 'ETHERS': None,
 'ETL': 'ETL',
 'EVENTSOURCING': 'EVENTSOURCING',
 'EXCEL': 'EXCEL',
 'EXCELLENT': None,
 'EXCHANGE': 'EXCHANGE',
 'EXECUTION': None,
 'EXPERIENCE': None,
 'EXPRESS': None,
 'EXP_LVL': None,
 'EXTENSIONS': None,
 'EXXI': None,
 'FABRIC': None,
 'FACTORY': None,
 'FAMILIARITY': None,
 'FI': 'FI',
 'FIDDLER': 'FIDDLER',
 'FIGURO': 'FIGURO',
 'FINANCE': None,
 'FINANCIAL': None,
 'FIREBASE': 'FIREBASE',
 'FIREBUG': 'FIREBUG',
 'FLASH': 'FLASH',
 'FLASK': 'FLASK',
 'FLEX': None,
 'FLOW': None,
 'FLUENT': None,
 'FLUTTER': 'FLUTTER',
 'FLUX': 'FLUX',
 'FME': None,
 'FOLLOWING': None,
 'FOR': None,
 'FOREMAN': None,
 'FORENSIC': None,
 'FORMS': None,
 'FOUNDATION': None,
 'FRAMEWORK': None,
 'FRAMEWORKS': None,
 'FRAMEWORKÓW': None,
 'FREEMARKER': None,
 'FRONT': None,
 'FRONTEND': None,
 'FS': None,
 'FUNCTIONAL': None,
 'FUNKCJONALNE': None,
 'FUNKCJONALNEJ': None,
 'FUSE': None,
 'GAME': None,
 'GATEWAYS': None,
 'GATLING': None,
 'GCC': 'GCC',
 'GCP': None,
 'GENERAL': None,
 'GERMAN': None,
 'GERRIT': None,
 'GIT': 'GIT',
 'GITFLOW': 'GIT',
 'GITHUB': 'GIT',
 'GITLAB': 'GIT',
 'GLSL': None,
 'GO': 'GO',
 'GOLANG': 'GO',
 'GOOD': None,
 'GOOGLE': None,
 'GPS': None,
 'GRADLE': 'GRADLE',
 'GRAFANA': 'GRAFANA',
 'GRAILS': 'GRAILS',
 'GRAPHIC': None,
 'GRAPHICS': None,
 'GRAPHQL': 'GRAPHQL',
 'GREAT': None,
 'GROOVY': 'GROOVY',
 'GRUNT': 'GRUNT',
 'GUI': None,
 'GUICE': 'GUICE',
 'GULP': 'GULP.JS',
 'HADOOP': 'HADOOP',
 'HANA': 'SAPHANA',
 'HANDLEBARS': 'HANDLEBARS.JS',
 'HANDLING': None,
 'HAPI': None,
 'HAPROXY': 'HAPROXY',
 'HAT': None,
 'HAXE': 'HAXE',
 'HBASE': 'HADOOP',
 'HDFS': 'HADOOP',
 'HIBERNATE': 'HIBERNATE',
 'HIGH': None,
 'HIVE': 'HADOOP',
 'HLSL': 'HIGH-LEVEL SHADING LANGUAGE',
 'HONESTY': None,
 'HORTONWORKS': 'HORTONWORKS',
 'HOTJAR': 'HOTJAR',
 'HOURS': None,
 'HP': None,
 'HTML': 'HTML',
 'HTTP': 'HTTP',
 'HYPER': None,
 'HYPERLEDGER': 'HYPERLEDGER',
 'ICMP': None,
 'IIS': 'IIS',
 'ILLUSTRATOR': 'ILUSTRATOR',
 'ILUSTRATOR': 'ILUSTRATOR',
 'IMAGE': None,
 'IMAGING': None,
'SCHEMA': None,
'SCIENCE': None,
'SCRAPY': 'MACHINELEARNING',
'SCRIPT': 'JAVASCRIPT',
'SCRIPTING': None,
'SCRUM': 'AGILE',
'SCSS': 'CSS',
'SCVMM': 'SCVMM',
'SD': None,
'SDK': 'ANDROID',
'SDLC': 'SDLC',
'SDN': 'SDN',
'SE': 'SEO',
'SEARCH': 'SEO',
'SECURITY': 'SECURITY',
'SELENIUM': 'SELENIUM',
'SELLENIUM': 'SELENIUM',
'SELLING': None,
'SENTRY': None,
'SEO': 'SEO',
'SEQUELIZE': 'NODEJS',
'SEQUEXPRESS': None,
'SERVER': 'SERVER',
'SERVERLESS': 'SERVER',
'SERVERS': 'SERVER',
'SERVICE': None,
'SERVICENOW': 'SERVICENOW',
'SERVICES': None,
'SHADING': None,
'SHAREPOINT': 'SHAREPOINT',
'SHELL': 'SHELL',
'SIECI': 'WEB',
'SIECIOWYCH': 'WEB',
'SIEM': 'SECURITY',
'SIMILAR': None,
'SIRI': None,
'SITECORE': 'NET',
'SKETCH': 'SKETCH',
'SKILLS': None,
'SKLEARN': 'MACHINELEARNING',
'SMART': None,
'SMARTCLIENT': None,
'SMARTY': 'PHP',
'SNAPKIT': None,
'SNMP': 'WEB',
'SNS': None,
'SOAP': 'WEB',
'SOAPUI': 'WEB',
'SOCKETT': None,
'SOFT': 'SOFTWARE',
'SOFTWARE': 'SOFTWARE',
'SOFTWRE': 'SOFTWARE',
'SOLID': 'PROGRAMMING',
'SOLIDITY': 'PROGRAMMING',
'SOLR': 'SOLR',
'SOLUTIONS': None,
'SOLVING': None,
'SOME': None,
'SONAR': 'SONAR',
'SONARQUBE': 'SONAR',
'SOURCE': None,
'SOVLING': None,
'SPA': None,
'SPARK': 'SPARK',
'SPEAKING': None,
'SPEECH': None,
'SPHINX': 'PYTHON',
'SPI': None,
'SPOCK': 'SPOCK',
'SPOKEN': None,
'SPREE': None,
'SPRING': 'SPRING',
'SQL': 'SQL',
'SQLALCHEMY': 'MACHINELEARNING',
'SQS': 'SQS',
'SRE': None,
'SSAS': 'SSAS',
'SSIS': 'SSIS',
'SSL': 'SSL',
'SSR': None,
'SSRS': 'SSRS',
'STABILNEJ': None,
'STACK': 'STACK',
'STACKS': 'STACK',
'STAR': None,
'STATISTIC': 'STATISTIC',
'STATISTICS': 'STATISTIC',
'STL': 'C++',
'STORAGE': None,
'STORIES': None,
'STREAM': None,
'STRUKTURALNIE': None,
'STUDIO': None,
'SUITE': None,
'SUPPORT': None,
'SVG': 'SVG',
'SVN': 'SUBVERSION',
'SWAGGER': 'SWAGGER',
'SWARM': None,
'SWIFT': None,
'SWING': None,
'SWITCHING': None,
'SYLIUS': 'SYLIUS',
'SYMFONY': 'SYMFONY',
'SYNTAX': None,
'SYPHONY': 'SYMFONY',
'SYSADMIN': 'SYSTEM',
'SYSTEM': 'SYSTEM',
'SYSTEMS': 'SYSTEM',
'SZYNA': None,
'TABELAU': None,
'TABLEAU': None,
'TAG': None,
'TCP': 'TCP',
'TDD': 'PROGRAMMING',
'TEAM': 'TEAMWORK',
'TEAMCITY': 'TEAMWORK',
'TEAMS': 'TEAMWORK',
'TEAMWORK': 'TEAMWORK',
'TECH': 'TECHNOLOGIES',
'TECHNICAL': 'TECHNOLOGIES',
'TECHNICZNA': 'TECHNOLOGIES',
'TECHNIQUES': 'TECHNOLOGIES',
'TECHNOLOGIES': 'TECHNOLOGIES',
'TECHNOLOGII': 'TECHNOLOGIES',
'TELEKOMUNIKACYJNE': None,
'TEMPLATES': None,
'TENSORFLOW': 'TENSORFLOW',
'TERADATA': 'TERADATA',
'TERRAFORM': 'TERRAFORM',
'TEST': 'TESTING',
'TESTER': 'TESTING',
'TESTFLIGHT': 'TESTING',
'TESTFLO': 'TESTING',
'TESTING': 'TESTING',
'TESTLINK': 'TESTING',
'TESTNG': 'TESTING',
'TESTOWANIE': 'TESTING',
'TESTRAIL': 'TESTING',
'TESTS': 'TESTING',
'TESTY': 'TESTING',
'TESTING' : None,
 'TESTLINK' : None,
 'TESTNG' : "TESTING",
 'TESTOWANIE' : None,
 'TESTRAIL' : None,
 'TESTS' : None,
 'TESTY' : "TESTS",
 'TESTÓW' : "TESTS",
 'TFS' : None,
 'THE': None,
 'THINKING' : None,
 'THREE' : None,
 'THRUK' : None,
 'TIME' : None,
 'TITLE' : None,
 'TLS': None,
 'TO': None,
 'TOMCAT': None,
 'TOOLS': None,
 'TOP': None,
 'TOUCH': None,
 'TRANSACT' : None,
 'TRANSFER' : None,
 'TRANSMISSION' : None,
 'TRIPS' : None,
 'TROUBLESHOOTING' : None,
 'TS' : None,
 'TWISTEAD' : "TWISTED",
 'TWISTED' : None,
 'TWITTER' : None,
 'TWORZENIE' : None,
 'TYPE' : None,
 'TYPESCRIPT' : None,
 'UART' : None,
 'UBUNTU' : None,
 'UC' : None,
 'UCD' : None,
 'UDP' : None,
 'UI': None,
 'UIKIT' : "UI",
 'UL': None,
 'UMBRACO' : None,
 'UMIEJĘTNOŚCI' : None,
 'UML' : None,
 'UNDER' : None,
 'UNDERSTANDING' : None,
 'UNIT' : None,
 'UNITS' : "UNIT",
 'UNITY' : None,
 'UNIX' : None,
 'UNNAMED' : None,
 'UNREAL' : None,
 'UP' : None,
 'USABILITY' : None,
 'USB' : None,
 'USER' : None,
 'UTRZYMANIE' : None,
 'UX' : None,
 'VB' : None,
 'VERSION' : None,
 'VISION' : None,
 'VISUAL' : None,
 'VISUALFORCE' : None,
 'VMS' : None,
 'VMWARE' : None,
 'VOIP' : None,
 'VUE' : None,
 'VUEJS': None,
 'VUEX' : None,
 'VULNERABILITY' : None,
 'WAREHOUSE' : None,
 'WAREHOUSING' : "WAREHOUSE",
 'WCAG' : None,
 'WCF' : None,
 'WDRAŻANIE' : None,
 'WEB' : None,
 'WEBAPI' : None,
 'WEBDRIVER' : None,
 'WEBFLUX' : None,
 'WEBGL' : None,
 'WEBLOGIC' : None,
 'WEBMETHODS' : None,
 'WEBPACK' : None,
 'WEBRTC' : None,
 'WEBSERVER' : None,
 'WEBSERVERS' : "WEBSERVER",
 'WEBSERVICE' : None,
 'WEBSERVICES' : "WEBSERVICE",
 'WEBSOCKET' : None,
 'WEBSOCKETS' : "WEBSOCKET",
 'WEBSPHERE' : None,
 'WEBTEST' : None,
 'WHICH' : None,
 'WIDZIANA' : None,
 'WILLINGNESS' : None,
 'WIN' : "WINDOWS",
 'WINDOWS' : None,
 'WINFORMS' : None,
 'WIREFRAMING' : None,
 'WITH' : None,
 'WM' : None,
 'WM<' : "VM",
 'WMI' : None,
 'WMS' : None,
 'WOOCOMMERCE' : None,
 'WORDPRESS' : None,
 'WORK' : None,
 'WORKED' : "WORK",
 'WORKING' : "WORK",
 'WPF' : None,
 'WRITER' : "WRITE",
 'WRITING' : "WRITE",
 'WRITTEN' : "WRITE",
 'WS' : None,
 'WSDL' : None,
 'WYKSZTAŁCENIE' : None,
 'WYŻSZE' : "WYKSZTAŁCENIE",
 'WZORCÓW' : None,
 'XAMARIN' : None,
 'XAML' : None,
 'XCODE' : None,
 'XCTEST' : None,
 'XD' : None,
 'XML' : None,
 'XP' : None,
 'XSD' : None,
 'XSLT' : None,
 'XSS' : None,
 'YAML' : None,
 'YARN' : None,
 'YEARS' : None,
 'ZABBIX' : None,
 'ZAGADNIEŃ' : None,
 'ZAPEWNIENIE' : None,
 'ZARZĄDZANIA' : "ZARZĄDZANIE",
 'ZARZĄDZANIE' : None,
 'ZEN' : None,
 'ZEND' : None,
 'ZEPLIN' : None,
 'ZNAJOMOŚĆ' : None,
         '>LE': 'LE',
    'A+': 'A+',
    'ABAP': 'ABAP',
    'ABILITY': None,
    'ACCEPTANCE': None,
    'ACCESS': 'ACCESS',
    'ACCOUNTING': None,
    'ACCOUNTS': None,
    'ACF': 'ACF',
    'ACTION': 'ACTION',
    'ACTIONSCRIPT': 'ACTIONSCRIPT',
    'ACTIVE': None,
    'AD': None,
    'ADB': 'ADB',
    'ADMINISTRATION': None,
    'ADMINISTRATOR': None,
    'ADOBE': 'ADOBE',
    'AGILE': 'AGILE',
    'AI': 'MACHINE LEARNING',
    'AIRFLOW': 'AIRFLOW',
    'AIX': 'AIX',
    'AJAX': 'AJAX',
    'AKKA': 'AKKA',
    'ALCHEMY': 'ALCHEMY',
    'ALEXA': 'ALEXA',
    'ALGORITHM': None,
    'ALGORITHMIC': None,
    'ALGORITHMS': None,
    'AMAZON': 'AMAZON',
    'AMINISTRACJA': None,
    'AN': None,
    'ANALITICAL': 'ANALYTICAL',
    'ANALITYCZNE': 'ANALYTICAL',
    'ANALIZA': 'ANALYSIS',
    'ANALYSIS': 'ANALYSIS',
    'ANALYST': 'ANALYST',
    'ANALYTICAL': 'ANALYTICAL',
    'ANALYTICS': 'ANALYTICS',
    'ANALYZER': 'ANALYZER',
    'AND': None,
    'ANDROID': 'ANDROID',
    'ANGIELSKI': None,
    'ANGIELSKIEGO': None,
    'ANGULAR': 'ANGULAR',
    'ANGULARJS': 'ANGULARJS',
    'ANOTHER': None,
    'ANSIBLE': None,
    'ANT': 'ANT',
    'ANULAR': 'ANGULAR',
    'APACHE': 'APACHE',
    'APEX': 'APEX',
    'API': 'API',
    'APIS': 'API',
    'APP': None,
    'APPCODE': 'APPCODE',
    'APPIUM': 'APPIUM',
    'APPLESCRIPT': 'APPLESCRIPT',
    'APPLICATION': None,
    'APPLICATIONS': None,
    'APPROACHES': None,
    'APPS': None,
    'APPSTORE': None,
    'AR': 'MACHINE LEARNING',
    'ARCGIS': 'ARCGIS',
    'ARCHITECTURE': 'ARCHITECTURE',
    'ARCHITEKTURA': 'ARCHITECTURE',
    'ARCORE': 'ARCORE',
    'ARM': None,
    'ARTIFICIAL': 'MACHINE LEARNING',
    'AS': None,
    'ASP': None,
    'ASPICE': None,
    'ASSERTIVENESS': None,
    'ASSETS': None,
    'ASSISTANT': None,
    'ASSURANCE': None,
    'ASVS': 'ASVS',
    'ASYNC': 'ASYNC',
    'ASYNCHRONOUS': None,
    'ASYNCIO': 'ASYNCIO',
    'AT': None,
    'ATTENTION': None,
    'ATTITUDE': None,
    'AUGMENTED': 'MACHINE LEARNING',
    'AUTO': None,
    'AUTOIT': 'AUTOIT',
    'AUTOMATED': None,
    'AUTOMATIC': 'AUTOMATION',
    'AUTOMATING': 'AUTOMATION',
    'AUTOMATION': 'AUTOMATION',
    'AUTOMATYCZNYCH': 'AUTOMATION',
    'AUTOMATYZACJA': 'AUTOMATION',
    'AUTOSAR': 'AUTOSAR',
    'AVAILABILITY': None,
    'AWS': 'AWS',
    'AX': None,
    'AXURE': 'AZURE',
    'AYTOLAYOUT': None,
    'AZURE': 'AZURE',
    'AZUREDEVOPS': 'AZURE',
    'BABEL': 'BABEL',
    'BACHELOR': None,
    'BACK': None,
    'BACKEND': 'BACKEND',
    'BACKGROUD': None,
    'BACKLOG': 'BACKLOG',
    'BACKUP': None,
    'BASH': 'BASH',
    'BASIC': None,
    'BATCH': 'BATCH',
    'BAZ': 'BAZ',
    'BAZAMI': 'BAZAMI',
    'BAZY': None,
    'BCP': 'BCP',
    'BDD': 'BDD',
    'BI': 'BI',
    'BIAS': 'BIAS',
    'BIG': None,
    'BIGDATA': 'BIGDATA',
    'BITBUCKET': 'BITBUCKET',
    'BIZNESOWA': None,
    'BLADE': 'BLADE',
    'BLOCKCHAIN': 'BLOCKCHAIN',
    'BLUETOOTH': None,
    'BOL': None,
    'BOOST': 'BOOST',
    'BOOT': None,
    'BOOTSTRAP': 'BOOTSTRAP',
    'BPM': None,
    'BPMN': None,
    'BPMP': None,
    'BROWSER': None,
    'BUG': None,
    'BUILDER': 'BUILDER',
    'BURP': None,
    'BUSINESS': None,
    'BUTTERKNIFE': 'BUTTERKNIFE',
    'BW': 'BW',
    'C#': 'C#',
    'C++': 'C++',
    'CAFFE': 'CAFFE'
}

# %%
dict7 = {}
for k, v in dict6.items():
    k_escaped = k.replace("+", "\+")
    dict7[k_escaped] = v
    
skills = list(sorted(set(filter(lambda x: x is not None, dict7.values()))))

# %%
import re


unified_df = df_info.copy()
for skill, target_skill in dict7.items():
    if target_skill is not None:
        try:
            col = unified_df[target_skill]
            temp = pd.DataFrame()
            temp['temp'] = df_offers.filter(regex=re.compile(rf"{skill}\b", re.I)).max(axis=1)
            temp[target_skill] = unified_df[target_skill]
            unified_df[target_skill] = temp[['temp', target_skill]].max(axis=1)
        except Exception:
            unified_df[target_skill] = df_offers.filter(regex=re.compile(skill, re.I)).max(axis=1)

# %%
import math

# sum(1 for x in list(unified_df["C++"]) if not math.isnan(float(x)))
# unified_df.JAVA.count()
t = unified_df[unified_df["company"] == "Mindbox S.A."].iloc[1, :]
t[t.notnull() == True]
# Out:
# company                 Mindbox S.A.
# emp_type                         B2B
# exp_lvl                            2
# title         QA Automation Engineer
# salary_min                     11000
# salary_max                     14000
# city                        Warszawa
# REST                               1
# JAVA                               4
# JENKINS                            4
# JMETER                             5
# MAVEN                              4
# GIT                                4
# SEO                                5
# SELENIUM                           5
# WEB                                5
# Name: 5, dtype: object

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split, GridSearchCV

import numpy as np
np.random.seed(42)

# %%
xgb_r = xgb.XGBRegressor(
    max_depth=5,
    learning_rate=0.07,
    n_estimators=1000,
    seed=42,
    n_jobs=-1,
    colsample_bytree=0.6
)

# %%
y = unified_df["salary_max"]
X = unified_df.drop(["salary_min",
                        "salary_max",
                        "company",
                        "emp_type",
                        "title"], axis=1)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
X['city'] = le.fit_transform(X['city'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42
)

# %%
xgb_r.fit(X_train, y_train)
# Out:
# /home/kodolamacz/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.6, gamma=0, importance_type='gain',
#        learning_rate=0.07, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=42, silent=True, subsample=1)

# %%
print(f"R^2 train: {r2_score(y_true=y_train, y_pred=xgb_r.predict(X_train))}")
print(f"R^2 test: {r2_score(y_true=y_test, y_pred=xgb_r.predict(X_test))}")

print(f"MAE train: {mean_absolute_error(y_true=y_train, y_pred=xgb_r.predict(X_train))}")
print(f"MAE test: {mean_absolute_error(y_true=y_test, y_pred=xgb_r.predict(X_test))}")
# Out:
# R^2 train: 0.9603683407556353
# R^2 test: 0.3742041030335409
# MAE train: 679.2372850263152
# MAE test: 2794.0265819040105

# %%
unified_df["salary_max"].max()
# Out:
# 33000.0

# %%
unified_df["salary_min"].min()
# Out:
# 600.0

# %%
X.loc[1, :] = np.nan

# %%
X.loc[1, ["JAVA"]] = 1
X.loc[1, ["JAVASCRIPT"]] = 1
X.loc[1, ["PYTHON"]] = 1

X.loc[1, ["EXCEL"]] = 1

X.loc[1, ["exp_lvl"]] = 3

# %%
xgb_r.predict(X.loc[0:1, :])
# Out:
# array([11389.961, 13565.6  ], dtype=float32)

# %%
import matplotlib.pyplot as plt
xgb.plot_importance(xgb_r, max_num_features=20)
plt.show()

# %%
t = unified_df[unified_df["company"] == "Mindbox S.A."].iloc[1, :]
t[t.notnull() == True]
# Out:
# company                 Mindbox S.A.
# emp_type                         B2B
# exp_lvl                            2
# title         QA Automation Engineer
# salary_min                     11000
# salary_max                     14000
# city                        Warszawa
# REST                               1
# JAVA                               4
# JENKINS                            4
# JMETER                             5
# MAVEN                              4
# GIT                                4
# SEO                                5
# SELENIUM                           5
# WEB                                5
# Name: 5, dtype: object

# %%
X['city'].head()
# Out:
# 0    15.0
# 1     NaN
# 2    33.0
# 3    34.0
# 4    33.0
# Name: city, dtype: float64

# %%
def how_much():
    X.loc[1, :] = np.nan
    exp_lvl = input("podaj ogólny exp lvl:")
    X.loc[1, ["exp_lvl"]] = int(exp_lvl)
    city = input("podaj miasto ziom:")
    X.loc[1, ["city"]] = le.transform([city])

    while True:
        skill = input("podaj technologie:")
        skill_lvl = input("podaj level")
        try:
            X.loc[1, [skill]] = int(skill_lvl)
        except:
            print("ziomeczku nie ma takiej technologii")
        next = input("czy chcesz podać nst? T/N")
        if next == "N":
            break;

    return xgb_r.predict(X.loc[1:1, :]) #moze byc 1:1 albo 0:1, niezalenie od modelu

# %%
X.loc[0:5, :]
# Out:
#    exp_lvl  city  C#  ACF  ADMINISTRACJA  ADOBE  ADWORDS  AGILE  \
# 0      3.0  15.0 NaN  NaN            NaN    NaN      NaN    NaN
# 1      2.0  15.0 NaN  NaN            NaN    NaN      NaN    NaN
# 2      2.0  33.0 NaN  NaN            NaN    NaN      NaN    NaN
# 3      2.0  34.0 NaN  NaN            NaN    NaN      NaN    NaN
# 4      2.0  33.0 NaN  NaN            NaN    NaN      NaN    NaN
# 5      2.0  33.0 NaN  NaN            NaN    NaN      NaN    NaN
#
#    MACHINE LEARNING  AIRFLOW  ...    BIGDATA  BITBUCKET  BLADE  BLOCKCHAIN  \
# 0               NaN      NaN  ...        NaN        NaN    NaN         NaN
# 1               NaN      NaN  ...        NaN        NaN    NaN         NaN
# 2               NaN      NaN  ...        NaN        NaN    NaN         NaN
# 3               NaN      NaN  ...        NaN        NaN    NaN         NaN
# 4               1.0      1.0  ...        NaN        NaN    NaN         NaN
# 5               NaN      NaN  ...        NaN        NaN    NaN         NaN
#
#    BOOST  BOOTSTRAP  BUILDER  BUTTERKNIFE  BW  CAFFE
# 0    NaN        NaN      NaN          NaN NaN    NaN
# 1    NaN        NaN      NaN          NaN NaN    NaN
# 2    NaN        NaN      NaN          NaN NaN    NaN
# 3    NaN        NaN      NaN          NaN NaN    NaN
# 4    NaN        NaN      NaN          NaN NaN    NaN
# 5    NaN        NaN      NaN          NaN NaN    NaN
#
# [6 rows x 386 columns]

# %%
print(how_much()[3])
# Out:
# podaj ogólny exp lvl:2
# podaj miasto ziom:Kraków
# podaj technologie:PYTHON
# podaj level2
# czy chcesz podać nst? T/NN
# 13686.399

# %%
print(how_much()[1])
# Out:
# podaj ogólny exp lvl:2
# podaj miasto ziom:Kraków
# podaj technologie:PYTHON
# podaj level2
# czy chcesz podać nst? T/NN
# 10914.275

# %%
print(how_much()[0])
# Out:
# podaj ogólny exp lvl:2
# podaj miasto ziom:Kraków
# podaj technologie:PYTHON
# podaj level2
# czy chcesz podać nst? T/NN
# 11389.961

# %%
print(how_much())
# Out:
# Podaj technologię: JAVA
# Podaj level: 1
# Czy chcesz podać następny? T/NPYTHON
# Podaj technologię: 2
# Podaj level: N
# Nie ma takiej technologii
# Czy chcesz podać następny? T/NT
# Podaj technologię: JIRA
# Podaj level: 5
# Czy chcesz podać następny? T/NN
# [11389.961 11839.556]
