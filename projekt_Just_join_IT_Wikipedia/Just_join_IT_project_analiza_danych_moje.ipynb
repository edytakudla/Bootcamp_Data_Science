# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 1300)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_seq_items', 2000)

# %%
df_offers = pd.read_csv("offers3.csv")
df_offers.head()
# Out:
#    Unnamed: 0  Unnamed: 1  .NET C#  .NET Core  .Net  .Net Architecture  \
# 0           0         NaN      NaN        NaN   NaN                NaN
# 1           1         NaN      NaN        NaN   NaN                NaN
# 2           2         NaN      NaN        NaN   NaN                NaN
# 3           3         NaN      NaN        NaN   NaN                NaN
# 4           4         NaN      NaN        NaN   NaN                NaN
#
#    .Net Framework (4.6+)  .net 4.5  2nd JVM language  \
# 0                    NaN       NaN               NaN
# 1                    NaN       NaN               NaN
# 2                    NaN       NaN               NaN
# 3                    NaN       NaN               NaN
# 4                    NaN       NaN               NaN
#
#    3 years as a project manager at minimum, an analyst, tester, operations or UX role as previous experience,  \
# 0                                                NaN
# ...

# %%
df_offers.shape
# Out:
# (1021, 1313)

# %%
columns = sorted(df_offers.columns.tolist())
columns
# Out:
# ['.NET C#',
#  '.NET Core',
#  '.Net',
#  '.Net Architecture',
#  '.Net Framework (4.6+)',
#  '.net 4.5',
#  '2nd JVM language',
#  '3 years as a project manager at minimum, an analyst, tester, operations or UX role as previous experience,',
#  '3D Assets',
#  '3D Models',
#  '3D graphics API: WebGL/OpenGL/Direct3D',
#  '3D graphics maths & algorithms',
#  'A/B testing',
#  'ABAP',
#  'ACF',
#  'AIX',
#  'ANT/ MAVEN',
#  'ANT/MAVEN',
#  'API',
#  'API Rest Tests',
#  'API integration',
#  'API testing',
#  'APIs and REST services',
#  'AR',
#  'ARCore',
#  'ARM',
#  'ASP .NET 4+',
#  'ASP .NET MVC',
#  'ASP MVC',
#  'ASP.NET',
#  'ASP.NET Core',
#  'ASP.NET MVC',
#  'ASP.NET MVC & JavaScript',
#  'ASP.NET Web API',
#  'ASP.Net WebAPI',
#  'ASPICE',
#  'AWS',
#  'AWS/Cloud',
#  'AWS/S3',
#  'Acceptance Tests',
#  'Access Control',
#  'Accounting',
#  'Accounting/Finance',
#  'Accounts Payable',
#  'Accounts Receivable',
#  'ActionScript',
#  'Active Directory',
#  'Adobe CC',
# ...

# %%
df_offers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1021 entries, 0 to 1020
# Columns: 1313 entries, Unnamed: 0 to Środowisko Linux
# dtypes: float64(1307), int64(2), object(4)
# memory usage: 10.2+ MB

# %%
columns2 = []
for col in columns:
    col = col.upper()
    columns2.append(col)
    
columns2
# Out:
# ['.NET C#',
#  '.NET CORE',
#  '.NET',
#  '.NET ARCHITECTURE',
#  '.NET FRAMEWORK (4.6+)',
#  '.NET 4.5',
#  '2ND JVM LANGUAGE',
#  '3 YEARS AS A PROJECT MANAGER AT MINIMUM, AN ANALYST, TESTER, OPERATIONS OR UX ROLE AS PREVIOUS EXPERIENCE,',
#  '3D ASSETS',
#  '3D MODELS',
#  '3D GRAPHICS API: WEBGL/OPENGL/DIRECT3D',
#  '3D GRAPHICS MATHS & ALGORITHMS',
#  'A/B TESTING',
#  'ABAP',
#  'ACF',
#  'AIX',
#  'ANT/ MAVEN',
#  'ANT/MAVEN',
#  'API',
#  'API REST TESTS',
#  'API INTEGRATION',
#  'API TESTING',
#  'APIS AND REST SERVICES',
#  'AR',
#  'ARCORE',
#  'ARM',
#  'ASP .NET 4+',
#  'ASP .NET MVC',
#  'ASP MVC',
#  'ASP.NET',
#  'ASP.NET CORE',
#  'ASP.NET MVC',
#  'ASP.NET MVC & JAVASCRIPT',
#  'ASP.NET WEB API',
#  'ASP.NET WEBAPI',
#  'ASPICE',
#  'AWS',
#  'AWS/CLOUD',
#  'AWS/S3',
#  'ACCEPTANCE TESTS',
#  'ACCESS CONTROL',
#  'ACCOUNTING',
#  'ACCOUNTING/FINANCE',
#  'ACCOUNTS PAYABLE',
#  'ACCOUNTS RECEIVABLE',
#  'ACTIONSCRIPT',
#  'ACTIVE DIRECTORY',
#  'ADOBE CC',
# ...

# %%
len(columns2)
# Out:
# 1313

# %%
len(set(columns2))
# Out:
# 1312

# %%
import re
columns3 = set()

for col in columns2:
    delete_chars = ["1", "2", "3", "4", "5", "6", "7", "8", "9", "0", " ", ".", "/", "_", ":", "'" ]
    for elem in delete_chars:
        col = col.replace(elem, "")
    columns3.add(col)
    
len(columns3)
# Out:
# 1220

# %%
len(set(columns3))
# Out:
# 1220

# %%
columns3
# Out:
# {'FLUTTER',
#  'JWT',
#  'MESOS',
#  'ANGULARX',
#  'BUSINESSANALYST',
#  'ISTGB',
#  'ITIL',
#  'MOBILEDEVELOPMENT',
#  'SASTDASTOSS',
#  'ANGULARANDORREACT',
#  'ANSIBLEPUPPET',
#  'SPRINGFRAMEWORK',
#  'COMPANY',
#  'UNREALENGINE',
#  'NEWRELIC',
#  'DATABASESYSTEMS',
#  'TESTCASECREATIONEXECUTIONANDREPORTING',
#  'MILEWIDZIANAZNAJOMOŚĆSPRINGFRAMEWORKORAZSOAPUI',
#  'JASPER',
#  'HDFS',
#  'ANGULARVUEREACT',
#  'NETWORKPROTOCOLS',
#  'HIGHAVAILABILITY',
#  'POLISH',
#  'BPMP',
#  'TDD',
#  'WM<->LEINTEGRATION',
#  'WINDOWSAPI',
#  'AUTOMATEDTESTING',
#  'BLADETEMPLATES',
#  'UISKILLS',
#  'CLOUDCOMPUTING(AWSORAZURE)',
#  'GOOGLETAGMANAGER',
#  'HIBERNATEJPA',
#  'CSSSASS',
#  'GROOVYGOPYTHON',
#  'APACHEHADOOP',
#  'SPAARCHITECTURE',
#  'JANGIELSKI',
#  'UCDPROCESS',
#  'AZUREDATAFACTORY',
#  'DASSETS',
#  'JASIMINE',
#  'MOBILETESTING',
#  'SPRING&HIBERNATE',
#  'WINDOWSADMINISTRATION',
#  'ZNAJOMOŚĆJAVAORAZECLIPSE,MAVEN,GIT',
#  'VMWARE',
#  'WEBSOCKETT',
# ...

# %%
# lepszy sposob na zmniejszenie listy kolumn
str = " ".join(columns).upper()
str = re.sub('[0-9\-,.:\/\(\)\'\"]', ' ', str)

new_list = [x for x in str.split(" ") if len(x) >= 2]
ue = set(new_list)
len(ue)
# Out:
# 1123

# %%
numerek = 2
sorted(ue)[(numerek-1)*141:numerek*141]
# Out:
# ['CALL',
#  'CAMEL',
#  'CAMERA',
#  'CAMUNDA',
#  'CANVAS',
#  'CARTHAGE',
#  'CASE',
#  'CASES',
#  'CASSANDRA',
#  'CC',
#  'CCNA',
#  'CCNP',
#  'CCS',
#  'CCTV',
#  'CD',
#  'CELERY',
#  'CENTER',
#  'CENTOS',
#  'CERTIFICATE',
#  'CERTIFIED',
#  'CHAI',
#  'CHANGE',
#  'CHEF',
#  'CHROME',
#  'CI',
#  'CITY',
#  'CLEAN',
#  'CLI',
#  'CLIENT',
#  'CLOJURE',
#  'CLOUD',
#  'CLOUDNATIVE',
#  'CMAKE',
#  'CMS',
#  'CO',
#  'COCOA',
#  'COCOAPODS',
#  'CODE',
#  'CODING',
#  'COFFEESCRIPT',
#  'COMMAND',
#  'COMMERCE',
#  'COMMITMENT',
#  'COMMU',
#  'COMMUNICATION',
#  'COMMUNICATIONS',
#  'COMPANY',
#  'COMPASS',
#  'COMPOSE',
#  'COMPOSER',
#  'COMPTIA',
#  'COMPUTER',
#  'COMPUTING',
#  'CONCEPTS',
#  'CONCRETE',
#  'CONFLICTS',
#  'CONFLUENCE',
#  'CONNECT',
#  'CONSUL',
#  'CONTACT',
#  'CONTAINER',
#  'CONTAINERS',
#  'CONTINOUS',
#  'CONTINUOUS',
#  'CONTRACTS',
#  'CONTROL',
#  'CORDOVA',
#  'CORE',
#  'COUNT',
#  'CRAFT',
#  'CREATING',
#  'CREATION',
#  'CREATIVE',
# ...

# %%
dict6 = {'#C' : "C#",
 'AAS': None,
 'ABSTRACT' : None,
 'ACF' : None,
 'ACTIVE' : "ACTIVEDIRECTORY",
 'ADMINISTRACJA': "ADMINISTRACJA",
 'ADMINISTRATION': "ADMINISTRACJA",
 'ADOBE' : None,
 'ADV' : None,
 'ADVANCED': None,
 'ADWORDS' : "ADWORDS",
 'AESTHETIC': None,
 'AFTER': None,
 'AGILE' : "Agile",
 'AI' : "AI",
 'AIRFLOW' : "AIRFLOW",
 'AKKA' : "AKKA",
 'ALGORITHMS' : 'ALGORITHMS',
 'ALM' : None,
 'AMAZON' : "AWS",
 'AMINISTRACJA' : "ADMINISTRACJA",
 'AMQP' : "ACTIVEMQ",
 'ANALITICAL' : None,
'ANALITYCZNE' : None,
'ANALYSIS' : None,
'ANALYST' : None,
'ANALYSTICS': None,
'ANALYTICS' : None,
'ANALYZER' : None,
'AND' : None,
'ANDROID' : "ANDROID",
'ANGIELSKI': "ENGLISH",
'ANGIELSKIEGO': "ENGLISH",
'ANGULAR' :"ANGULARJS",
'ANGULARJS' : "ANGULARJS",
'ANIMATIONS': None,
'ANSIBLE': "ANSIBLE",
'ANT':"ANT",
'ANY':None,
'APACHE':None,
'APEX':'APEX',
'API':None,
'APIS':None,
'APLIKACJI':None,
'APP':None,
'APPCODE' : "APPCODE",
'APPIUM': "APPIUM",
'APPLICATIONS':None,
'APPROACH':None,
'APPS':None,
'AR':None,
'ARCHITECTURE':"ARCHITECTURE",
'ARCHITEKT':"ARCHITECTURE",
'ARM':"ARM",
'ARP':None,
'ARTIFACTORY' : 'ARTIFACTORY',
'AS':None,
'ASP' : "ASP",
'ASPICE' : None,
'ASSURANCE' : None,
'ASYNC' : None,
'ATTITUDE' : None,
'AUTOFAC' : None,
'AUTOMATED':None,
'AUTOMATING':None,
'AUTOMATION':None,
'AUTOMATYCZNYCH':None,
'AUTOMOTIVE':None,
'AUTOSAR':None,
'AVAILABILITY':None,
 'PLANING':'PLANNING',
 'PLATFORM':None,
 'PLATFORMS':None,
 'PLAYER':None,
 'PLIKOWE':None,
 'PLUGIN':None,
 'PM':'PROJECTMANAGEMENT',
 'PMBOK':'PROJECTMANAGEMENT',
 'POI':None,
 'POINT':None,
 'POKREWNE':None,
 'POLISH':'POLISH',
 'POPRAWA':None,
 'POSIX':'POSIX',
 'POSTGRES':'POSTGRESQL',
 'POSTGRESQL':'POSTGRESQL',
 'POSTMAN':'POSTMAN',
 'POSTRESQL':'POSTGRESQL',
 'POWER':None,
 'POWERSHELL':'POWERSHELL',
 'POZIOMIE':None,
 'PRACTICES':None,
 'PRACY':None,
 'PREFEROWANE':None,
 'PREPARTATION':None,
 'PREPROCESSORS':None,
 'PRESSURE':None,
 'PRESTASHOP':'PRESTASHOP',
 'PREVIOUS':None,
 'PRIMEFACES':'PRIMEFACES',
 'PRINCE':'PRINCE2',
 'PRINCIPLES':None,
 'PRO':None,
 'PROACTIVITY':None,
 'PROBLEM':None,
 'PROCEDURE':None,
 'PROCESS':None,
 'PROCESSING':None,
 'PRODUCT':None,
 'PRODUCTS':None,
 'PROGRAMING':'PROGRAMMING',
 'PROGRAMMING':'PROGRAMMING',
 'PROGRAMOWANIU':'PROGRAMMING',
 'PROJECT':None,
 'PROJECTS':None,
 'PROJEKTAMI':None,
 'PROJEKTOWANIE':None,
 'PROJEKTOWYCH':None,
 'PROMETHEUS':'PROMETHEUS',
 'PROMISE':None,
 'PROTOCOL':'PROTOCOLS',
 'PROTOCOLS':'PROTOCOLS',
 'PROTOTYPEJS':'PROTOTYPING',
 'PROTOTYPING':'PROTOTYPING',
 'PROTRACTOR':'PROTRACTOR',
 'PS':'PHOTOSHOP',
 'PSM':'PSM',
 'PSR':'PSR',
 'PTES':'PTES',
 'PUPPET':'PUPPET',
 'PWA':'PWA',
 'PYHTON':'PYTHON',
 'PYRAMID':'PYRAMID',
 'PYTH':'PYTHON',
 'PYTHON':'PYTHON',
 'PYTORCH':'PYTORCH',
 'QA':'QA',
 'QLICKVIEW':'QLIKVIEW',
 'QML':'QML',
 'QT':'QT',
 'QTEST':'QTEST',
 'QTP':'QTP',
 'QUALITY':None,
 'QUICK':None,
 'RABBITMQ':'RABBITMQ',
 'RAILS':'RUBY ON RAILS',
 'RDBMS':'RDBMS',
 'REACT':'REACTJS',
 'REACT&REDUX':'REACTJS',
 'REACTJS':'REACTJS',
 'REACTRXJS':'REACTJS',
 'READINESS':None,
 'REALITY':None,
 'RECEIVABLE':None,
 'RECOVERY':None,
 'RED':None,
 'REDHAT':'REDHAT',
 'REDIS':'REDIS',
 'REDPRAIRIE':'REDPRAIRIE',
 'REDUCE':None,
 'REDUX':'REDUX',
 'REGISTRY':None,
 'REGRESSION':None,
 'RELACYJNE':None,
 'RELATIONAL':'SQL',
 'RELIABILITY':None,
 'REMOTE':None,
 'REPORT':None,
 'REPORTING':'REPORTING',
 'REPORTS':'REPORTING',
 'REQUIREMENTS':None,
 'RESEARCH':'RESEARCH',
 'RESPONSE':None,
 'RESPONSIVE':None,
 'REST':'REST',
 'RESTFUL':'REST',
 'RETROFIT':'RETROFIT',
 'REVIEW':None,
 'REVIEWS':None,
 'ROBOT':'ROBOT',
 'ROLE':None,
 'ROOM':None,
 'ROR':None,
 'ROSYJSKI':'RUSSIAN',
 'ROUTING':'ROUTING',
 'ROZWIĄZAŃ':None,
 'RPA':'RPA',
 'RSPEC':'RSPEC',
 'RTOS':'RTOS',
 'RUBY':'RUBYONRAILS',
 'RUNNING':None,
 'RWD':'RWD',
 'RX':'RX',
 'RXCOCOA':'RXCOCOA',
 'RXJAVA':'RX',
 'RXJS':'RX',
 'RXKOTLIN':'RX',
 'RXSWIFT':'RX',
 'SAAS':'SAAS',
 'SAFE':None,
 'SALARY_MAX':None,
 'SALARY_MIN':None,
 'SALESFORCE':'SALESFORCE',
 'SAMLV':'SAMLV',
 'SAOP':'SAOP',
 'SAP':'SAP',
 'SASS':'SAAS',
 'SAST':'SAST',
 'SCALA':'SCALA',
 'SCALABILITY':None,
 'SCENARIOS':None,
 'IMPALA': 'IMPALA',
 'IN': None,
 'INBOUND': None,
 'INCIDENT': None,
 'INDUSTRY': None,
 'INFLUXDB': 'INFLUXDB',
 'INFORMATYCZNE': None,
 'INFRASTRUKTURY': None,
 'INJECTION': None,
 'INNYCH': None,
 'INTEGRACYJNYCH': None,
 'INTEGRATION': None,
 'INTELLIGENCE': 'MACHINELEARNING',
 'INTELLIJ': 'INTELLIJ',
 'INTERACTION': None,
 'INTERFEJSY': None,
 'INTERFEJSÓW': None,
 'INTERNALS': None,
 'INVENTORY': None,
 'INVISION': 'INVISION',
 'IO': None,
 'IONIC': 'IONIC',
 'IOS': 'IOS',
 'IOT': 'IOT',
 'IP': 'IP',
 'IPC': None,
 'IPV': None,
 'ISO': 'ISO',
 'ISOMORPHIC': 'ISOMORPHIC',
 'ISTGB': 'ISTQB',
 'ISTQB': 'ISTQB',
 'IT': None,
 'ITIL': 'ITIL',
 'IVR': 'IVR',
 'JAMF': 'JAMF',
 'JASIMINE': 'JASMINE',
 'JASMIN': 'JASMINE',
 'JASMINE': 'JASMINE',
 'JASPER': 'JASPER',
 'JAVA': 'JAVA',
 'JAVASCRIP': 'JAVASCRIPT',
 'JAVASCRIPT': 'JAVASCRIPT',
 'JBEHAVE': 'JBEHAVE',
 'JBOSS': 'JBOSS',
 'JCR': 'JCR',
 'JEE': 'JAVA',
 'JENINKS': 'JENKINS',
 'JENKINS': 'JENKINS',
 'JENKIS': 'JENKINS',
 'JEST': 'JEST',
 'JETTY': 'JETTY',
 'JIRA': 'JIRA',
 'JLINK': 'JLINK',
 'JM': 'JMETER',
 'JMETER': 'JMETER',
 'JPA': 'JAVA',
 'JQUERRY': 'JQUERY',
 'JQUERY': 'JQUERY',
 'JS': 'JAVASCRIPT',
 'JSF': 'JAVA',
 'JSON': 'JSON',
 'JUNIT': 'JUNIT',
 'JVM': 'JVM',
 'JWT': 'JASON',
 'JĘZYK': None,
 'JĘZYKA': None,
 'KAFKA': 'KAFKA',
 'KANBAN': 'KANBAN',
 'KARAF': 'KARAF',
 'KARMA': 'KARMA',
 'KATALON': 'KATALON',
 'KERAS': 'KERAS',
 'KERBEROS': 'KERBEROS',
 'KIERUNKI': None,
 'KIF': None,
 'KNOCKOUT': 'KNOCKOUT',
 'KNOWLEDGE': None,
 'KOMPUTERÓW': None,
 'KOMUNIKACYJNE': None,
 'KOMUNIKATYWNYM': None,
 'KORPORACYJNA': None,
 'KOTLIN': 'KOTLIN',
 'KREATYWNOŚĆ': None,
 'KUBERNATES': 'KUBERNETES',
 'KUBERNE': 'KUBERNETES',
 'KUBERNETES': 'KUBERNETES',
 'KVM': 'KVM',
 'LAKE': None,
 'LANGUAGE': None,
 'LANGUAGES': None,
 'LARAVEL': 'LARAVEL',
 'LARGE': None,
 'LAYOUT': None,
 'LDAP': 'LDAP',
 'LEADERSHIP': 'LEADERSHIP',
 'LEADING': 'LEADERSHIP',
 'LEAN': 'LEAN',
 'LEARNING': 'LEARNING',
 'LESS': 'LESS',
 'LIBGDX': 'LIBGDX',
 'LIBVIRT': 'LIBVIRT',
 'LIFECYCLE': None,
 'LIFERAY': 'LIFERAY',
 'LIGHTNING': None,
 'LINE': None,
 'LINQ': 'LINQ',
 'LINUX': 'LINUX',
 'LO': None,
 'LOGIC': None,
 'LOGICAL': None,
 'LOKALNEJ': None,
 'LOW': None,
 'LUB': None,
 'LUCENE': 'LUCENE',
 'LUMIRA': 'LUMIRA',
 'LWJGL': 'LWJGL',
 'MACHINE': 'MACHINELEARNING',
 'MAGENTO': 'MAGENTO',
 'MAKING': None,
 'MANAGAMENT': 'MANAGEMENT',
 'MANAGEMENT': 'MANAGEMENT',
 'MANAGER': 'MANAGEMENT',
 'MANAGING': 'MANAGEMENT',
 'MANAGMENT': 'MANAGEMENT',
 'MANUAL': None,
 'MAP': None,
 'MARATHON': None,
 'MARIADB': 'MARIADB',
 'MARKET': None,
 'MARKUP': 'MARKUP',
 'MASONRY': 'MASONRY',
 'MASTER': None,
 'MATERIAL': None,
 'MATHS': 'MATHS',
 'MAVEN': 'MAVEN',
 'MAVN': 'MAVEN',
 'MDM': 'MDM',
 'MEDICAL': None,
 'MEMCACHE': 'MEMCACHE',
 'MEMCACHED': 'MEMCACHE',
 'MENAGMENT': 'MANAGEMENT',
 'CALL' : None,
 'CAMEL' : 'CAMEL',
 'CAMERA' : None,
 'CAMUNDA' : 'CAMUNDA',
 'CANVAS' : 'CANVAS',
 'CARTHAGE' : 'CARTHAGE',
 'CASE' : None,
 'CASES' : None,
 'CASSANDRA' : 'CASSANDRA',
 'CC' : 'CC',
 'CCNA' : 'CC',
 'CCNP' : 'CC',
 'CCS' : 'CC',
 'CCTV' : 'CC',
 'CD' : None,
 'CELERY' : 'CELERY',
 'CENTER' : None,
 'CENTOS' : 'CENTOS',
 'CERTIFICATE' : None,
 'CERTIFIED' : None,
 'CHAI' : 'CHAI',
 'CHANGE' : None,
 'CHEF' : None,
 'CHROME' : 'CHROME',
 'CI' : 'CI',
 'CITY' : None,
 'CLEAN' : None,
 'CLI' : None,
 'CLIENT' : None,
 'CLOJURE' : 'CLOJURE',
 'CLOUD' : 'CLOUD',
 'CLOUDNATIVE' : 'CLOUD',
 'CMAKE' : 'CMAKE',
 'CMS' : 'CMS',
 'CO' : 'CO',
 'COCOA' : 'CO',
 'COCOAPODS' : 'CO',
 'CODE' : None,
 'CODING' : None,
 'COFFEESCRIPT' : 'COFFEESCRIPT',
 'COMMAND' : None,
 'COMMERCE' : 'E-COMMERCE',
 'COMMITMENT' : None,
 'COMMU' : None,
 'COMMUNICATION' : None,
 'COMMUNICATIONS' : None,
 'COMPANY' : None,
 'COMPASS' : 'COMPASS',
 'COMPOSE' : 'COMPOSER',
 'COMPOSER' : 'COMPOSER',
 'COMPTIA' : 'COMPTIA',
 'COMPUTER' : None,
 'COMPUTING' : None,
 'CONCEPTS' : None,
 'CONCRETE' : None,
 'CONFLICTS' : None,
 'CONFLUENCE' : None,
 'CONNECT' : 'CONNECT',
 'CONSUL' : 'CONSUL',
 'CONTACT' : None,
 'CONTAINER' : 'CONTAINER',
 'CONTAINERS' : 'CONTAINER',
 'CONTINOUS' : None,
 'CONTINUOUS' : None,
 'CONTRACTS' : None,
 'CONTROL' : None,
 'CORDOVA' : 'CORDOVA',
 'CORE' : None,
 'COUNT' : None,
 'CRAFT' : 'CRAFT',
 'CREATING' : None,
 'CREATION' : None,
 'CREATIVE' : None,
 'CRITICAL' : None,
 'CRM' : 'CRM',
 'CROSS' : None,
 'CRYPTOGRAPHIC' : 'CRYPTOGRAPHY',
 'CRYPTOGRAPHY': 'CRYPTOGRAPHY',
 'CSS' : 'CSS',
 'CUCUMBER' : 'CUCUMBER',
 'CURL' : None,
 'CUSTOMER' : None,
 'CXF' : 'CXF',
 'CYBERSECURITY' : 'CYBERSECURITY',
 'CYPRESS' : 'CYBERSECURITY',
 'DAGGER' : 'DAGGER',
 'DANYCH' : None,
 'DAO' : 'DATAACCESSOBJECT',
 'DAST' : 'DYNAMICAPPLICATIONSECURITYTESTING',
 'DATA' : None,
 'DATABASE' : 'DATABASES',
 'DATABASES' : 'DATABASES',
 'DATADOG' : 'DATADOG',
 'DAX' : 'DAX',
 'DB' : 'DATABASES',
 'DDD' : 'DATADRIVENDEVELOPMENT',
 'DEBIAN' : 'DEBIAN',
 'DEBUGGING' : None,
 'DECISION' : None,
 'DEEP' : 'DEEPLEARNING',
 'DEFINING' : None,
 'DEGREE' : None,
 'DELEGATION' : None,
 'DELIVERIES' : None,
 'DELIVERY' : None,
 'DEPENDENCY' : None,
 'DEPLOYMENT' : None,
 'DESIGN' : 'DESIGNING',
 'DESIGNING' : 'DESIGNING',
 'DESK' : None,
 'DETAIL' : None,
 'DEV' : 'DEVELOPMENT',
 'DEVELOPER' : 'DEVELOPMENT',
 'DEVELOPING' : 'DEVELOPMENT',
 'DEVELOPMENT' : 'DEVELOPMENT',
 'DEVICE' : None,
 'DEVICES' : None,
 'DEVOPS' : 'DEVOPS',
 'DHCP' : 'DHCP',
 'DIGITAL' : None,
 'DIRECT' : None,
 'DIRECTORY' : 'ACTIVEDIRECTORY',
 'DIRECTX' : 'DIRECTX',
 'DISTRIBUTED' : None,
 'DJANGO' : 'DJANGO',
 'DLANGO' : 'DJANGO',
 'DLT' : 'DLT',
 'DNS' : 'DNS',
 'DOCKE' : 'DOCKER',
 'DOCKER' : 'DOCKER',
 'DOCTRINE' : None,
 'DOKUMENTACJA' : None,
 'DOŚWIADCZENIE' : None,
 'DRF' : 'DRF',
 'DRIVER' : None,
 'DRUPAL' : 'DRUPAL',
 'DSC' : 'DSC',
 'DSDM' : 'DSDM',
 'DSP' : 'DSP',
 'DWH' : 'DWH',
 'DYNAMICS': 'CRM',
  'NUXT':'NUXTJS',
  'OBJECT':'OBJECT',
 'OBJECTIVE':'OBJECT',
 'ODATA':'ODATA',
 'ODOO':'ODOO',
 'OF':None,
 'OFFICE':'OFFICE',
 'OLTP':'OLTP',
 'ON':None,
 'ONOS':None,
 'OOP':'OBJECT',
 'OPEN':None,
 'OPENCV':'OPENCV',
 'OPENFL':'OPENFL',
 'OPENGL':'OPENGL',
 'OPENJPA':'OPENJPA',
 'OPENSHIFT':'OPENSHIFT',
 'OPENSTACK':'OPENSTACK',
 'OPERATIONS':None,
 'OPSGENIE':'OPSGENIE',
 'OPTIMIZATION':None,
 'OR':None,
 'ORACLE':'ORACLE',
 'ORAZ':None,
 'ORDER':None,
 'ORGANISATION':None,
 'ORGANIZATION':None,
 'ORIENTED':None,
 'ORM':'ORM',
 'OS':'OS',
 'OSOBISTYCH':None,
 'OSS':'OSS',
 'OTHER':None,
 'OTRS':'OTRS',
 'OUTBOUND':None,
 'OVIRT':'OVIRT',
 'OWASP':'OWASP',
 'OWNERSHIP':None,
 'PACKER':'None',
 'PANDAS':'PANDAS',
 'PASSION':None,
 'PATIENCE':None,
 'PATTERNS':None,
 'PATTERS':None,
 'PAYABLE':None,
 'PBX':'PBX',
 'PENTAHO':'PENTAHO',
 'PENTESTING':'PENTESTING',
 'PEOPLE':None,
 'PEP':None,
 'PERFORMANCE':None,
 'PERL':'PERL',
 'PERSISTENCE':None,
 'PHASER':'PHASER',
 'PHOTON':None,
 'PHOTOSHOP':'PHOTOSHOP',
 'PHP':'PHP',
 'PHPUNIT':'PHP',
 'PIG':None,
 'PIPELINE':None,
 'PIXIJS':'PIXIJS',
 'PIŚMIE':None,
 'PL':None,
 'PLAN':None,
 'PLANET':'PLANET',
 'PLANING':None,
 'PLATFORM':None,
 'PLATFORMS':None,
 'PLAYER':None,
 'PLIKOWE':None,
 'PLUGIN':None,
 'PM':'PROJECTMANAGER',
 'PMBOK':'PROJECTMANAGER',
 'POI':None,
 'POINT':None,
 'POKREWNE':None,
 'POLISH':'POLISH',
 'POPRAWA':None,
 'POSIX':'POSIX',
 'POSTGRES':'POSTGRESQL',
 'POSTGRESQL':'POSTGRESQL',
 'POSTMAN':'POSTMAN',
 'POSTRESQL':'POSTGRESQL',
 'POWER':'POWERSHELL',
 'POWERSHELL':'POWERSHELL',
 'POZIOMIE':None,
 'PRACTICES':None,
 'PRACY':None,
 'PREFEROWANE':None,
 'PREPARTATION':None,
 'PREPROCESSORS':None,
 'PRESSURE':None,
 'PRESTASHOP':'PRESTASHOP',
 'PREVIOUS':None,
 'PRIMEFACES':'PRIMEFACES',
 'PRINCE':None,
 'PRINCIPLES':None,
 'PRO':None,
 'PROACTIVITY':None,
 'PROBLEM':None,
 'PROCEDURE':None,
 'PROCESS':None,
 'PROCESSING':None,
 'PRODUCT':None,
 'PRODUCTS':None,
 'PROGRAMING':None,
 'PROGRAMMING':None,
 'PROGRAMOWANIU':None,
 'PROJECT':None,
 'PROJECTS':None,
 'PROJEKTAMI':None,
 'PROJEKTOWANIE':None,
 'PROJEKTOWYCH':None,
 'PROMETHEUS':'PROMETHEUS',
 'PROMISE':'PROMISE',
 'PROTOCOL':None,
 'PROTOCOLS':None,
 'PROTOTYPEJS':'PROTOTYPEJS',
 'PROTOTYPING':None,
 'PROTRACTOR':'PROTRACTOR',
 'PS':'PLAY STATION',
 'PSM':None,
 'PSR':None,
 'PTES':'PENTESTS',
 'PUPPET':'PUPPET',
 'PWA':'PWA',
 'PYHTON':'PYTHON',
 'PYRAMID':None,
 'PYTH':'PYTHON',
 'PYTHON':'PYTHON',
 'PYTORCH':'MACHINELEARNING',
 'QA':'QUALITYASSURANCE',
 'QLICKVIEW':'QUICKVIEW',
 'QML':'QML',
 'QT':'QT',
 'QTEST':'QUALITYASSURANCE',
 'QTP':'QTP',
 'QUALITY':'QUALITYASSURANCE',
 'QUICK':'QUICKVIEW',
 'RABBITMQ':'RABBITMQ',
 'RAILS':'RUBY',
 'RDBMS':'RDBMS',
 'REACT':'REACTJS',
 'REACT&REDUX':'REACTJS',
 'REACTJS':'REACTJS',
 'REACTRXJS':'REACTJS',
 'READINESS':None,
 'REALITY':None,
 'RECEIVABLE':None,
'RECOVERY':None,
 'RED':'REDHAT',
 'REDHAT':'REDHAT',
 'REDIS':'REDIS',
 'REDPRAIRIE':'REDPRAIRIE',
 'REDUCE':None,
 'REDUX':None,
 'REGISTRY':None,
 'REGRESSION':'MACHINELEARNING',
 'RELACYJNE':None,
 'RELATIONAL':None,
  'EARLGREY': 'EARLGREY',
 'ECCOMERCE': 'E-COMMERCE',
 'ECLIPSE': 'ECLIPSE',
 'ECMASCRIPT': 'JAVASCRIPT',
 'ECOMMERCE': 'E-COMMERCE',
 'EDI': 'EDI',
 'EE': None,
 'EIP': None,
 'EIXIR': 'ELIXIR',
 'EJB': 'EJB',
 'ELASTIC': 'ELASTICSEARCH',
 'ELASTICSEARCH': 'ELASTICSEARCH',
 'ELECTRON': None,
 'ELEMENTS': None,
 'ELIXIR': 'ELIXIR',
 'ELK': None,
 'ELT': None,
 'EMBEDDED': 'EMBEDDED',
 'EMBER': 'EMBER.JS',
 'EMPATHY': 'EMPATHY',
 'EMP_TYPE': None,
 'END': None,
 'ENERGY': None,
 'ENGINE': None,
 'ENGLISH': 'ENGLISH',
 'ENTERPRISE': None,
 'ENTITI': 'ENTITYFRAMEWORK',
 'ENTITY': 'ENTITYFRAMEWORK',
 'ENVIRONMENT': None,
 'ERP': None,
 'ES': 'JAVASCRIPT',
 'ESB': 'ENTERPRISESERVICEBUS',
 'ESNEXT': 'JAVASCRIPT',
 'ESPRESSO': 'ESPRESSO',
 'ETC': None,
 'ETHERS': None,
 'ETL': 'ETL',
 'EVENTSOURCING': 'EVENTSOURCING',
 'EXCEL': 'EXCEL',
 'EXCELLENT': None,
 'EXCHANGE': 'EXCHANGE',
 'EXECUTION': None,
 'EXPERIENCE': None,
 'EXPRESS': None,
 'EXP_LVL': None,
 'EXTENSIONS': None,
 'EXXI': None,
 'FABRIC': None,
 'FACTORY': None,
 'FAMILIARITY': None,
 'FI': 'FI',
 'FIDDLER': 'FIDDLER',
 'FIGURO': 'FIGURO',
 'FINANCE': None,
 'FINANCIAL': None,
 'FIREBASE': 'FIREBASE',
 'FIREBUG': 'FIREBUG',
 'FLASH': 'FLASH',
 'FLASK': 'FLASK',
 'FLEX': None,
 'FLOW': None,
 'FLUENT': None,
 'FLUTTER': 'FLUTTER',
 'FLUX': 'FLUX',
 'FME': None,
 'FOLLOWING': None,
 'FOR': None,
 'FOREMAN': None,
 'FORENSIC': None,
 'FORMS': None,
 'FOUNDATION': None,
 'FRAMEWORK': None,
 'FRAMEWORKS': None,
 'FRAMEWORKÓW': None,
 'FREEMARKER': None,
 'FRONT': None,
 'FRONTEND': None,
 'FS': None,
 'FUNCTIONAL': None,
 'FUNKCJONALNE': None,
 'FUNKCJONALNEJ': None,
 'FUSE': None,
 'GAME': None,
 'GATEWAYS': None,
 'GATLING': None,
 'GCC': 'GCC',
 'GCP': None,
 'GENERAL': None,
 'GERMAN': None,
 'GERRIT': None,
 'GIT': 'GIT',
 'GITFLOW': 'GIT',
 'GITHUB': 'GIT',
 'GITLAB': 'GIT',
 'GLSL': None,
 'GO': 'GO',
 'GOLANG': 'GO',
 'GOOD': None,
 'GOOGLE': None,
 'GPS': None,
 'GRADLE': 'GRADLE',
 'GRAFANA': 'GRAFANA',
 'GRAILS': 'GRAILS',
 'GRAPHIC': None,
 'GRAPHICS': None,
 'GRAPHQL': 'GRAPHQL',
 'GREAT': None,
 'GROOVY': 'GROOVY',
 'GRUNT': 'GRUNT',
 'GUI': None,
 'GUICE': 'GUICE',
 'GULP': 'GULP.JS',
 'HADOOP': 'HADOOP',
 'HANA': 'SAPHANA',
 'HANDLEBARS': 'HANDLEBARS.JS',
 'HANDLING': None,
 'HAPI': None,
 'HAPROXY': 'HAPROXY',
 'HAT': None,
 'HAXE': 'HAXE',
 'HBASE': 'HADOOP',
 'HDFS': 'HADOOP',
 'HIBERNATE': 'HIBERNATE',
 'HIGH': None,
 'HIVE': 'HADOOP',
 'HLSL': 'HIGH-LEVELSHADINGLANGUAGE',
 'HONESTY': None,
 'HORTONWORKS': 'HORTONWORKS',
 'HOTJAR': 'HOTJAR',
 'HOURS': None,
 'HP': None,
 'HTML': 'HTML',
 'HTTP': 'HTTP',
 'HYPER': None,
 'HYPERLEDGER': 'HYPERLEDGER',
 'ICMP': None,
 'IIS': 'IIS',
 'ILLUSTRATOR': 'ILUSTRATOR',
 'ILUSTRATOR': 'ILUSTRATOR',
 'IMAGE': None,
 'IMAGING': None,
'SCHEMA': None,
'SCIENCE': None,
'SCRAPY': 'MACHINELEARNING',
'SCRIPT': 'JAVASCRIPT',
'SCRIPTING': None,
'SCRUM': 'AGILE',
'SCSS': 'CSS',
'SCVMM': 'SCVMM',
'SD': None,
'SDK': 'ANDROID',
'SDLC': 'SDLC',
'SDN': 'SDN',
'SE': 'SEO',
'SEARCH': 'SEO',
'SECURITY': 'SECURITY',
'SELENIUM': 'SELENIUM',
'SELLENIUM': 'SELENIUM',
'SELLING': None,
'SENTRY': None,
'SEO': 'SEO',
'SEQUELIZE': 'NODEJS',
'SEQUEXPRESS': None,
'SERVER': 'SERVER',
'SERVERLESS': 'SERVER',
'SERVERS': 'SERVER',
'SERVICE': None,
'SERVICENOW': 'SERVICENOW',
'SERVICES': None,
'SHADING': None,
'SHAREPOINT': 'SHAREPOINT',
'SHELL': 'SHELL',
'SIECI': 'WEB',
'SIECIOWYCH': 'WEB',
'SIEM': 'SECURITY',
'SIMILAR': None,
'SIRI': None,
'SITECORE': 'NET',
'SKETCH': 'SKETCH',
'SKILLS': None,
'SKLEARN': 'MACHINELEARNING',
'SMART': None,
'SMARTCLIENT': None,
'SMARTY': 'PHP',
'SNAPKIT': None,
'SNMP': 'WEB',
'SNS': None,
'SOAP': 'WEB',
'SOAPUI': 'WEB',
'SOCKETT': None,
'SOFT': 'SOFTWARE',
'SOFTWARE': 'SOFTWARE',
'SOFTWRE': 'SOFTWARE',
'SOLID': 'PROGRAMMING',
'SOLIDITY': 'PROGRAMMING',
'SOLR': 'SOLR',
'SOLUTIONS': None,
'SOLVING': None,
'SOME': None,
'SONAR': 'SONAR',
'SONARQUBE': 'SONAR',
'SOURCE': None,
'SOVLING': None,
'SPA': None,
'SPARK': 'SPARK',
'SPEAKING': None,
'SPEECH': None,
'SPHINX': 'PYTHON',
'SPI': None,
'SPOCK': 'SPOCK',
'SPOKEN': None,
'SPREE': None,
'SPRING': 'SPRING',
'SQL': 'SQL',
'SQLALCHEMY': 'MACHINELEARNING',
'SQS': 'SQS',
'SRE': None,
'SSAS': 'SSAS',
'SSIS': 'SSIS',
'SSL': 'SSL',
'SSR': None,
'SSRS': 'SSRS',
'STABILNEJ': None,
'STACK': 'STACK',
'STACKS': 'STACK',
'STAR': None,
'STATISTIC': 'STATISTIC',
'STATISTICS': 'STATISTIC',
'STL': 'C++',
'STORAGE': None,
'STORIES': None,
'STREAM': None,
'STRUKTURALNIE': None,
'STUDIO': None,
'SUITE': None,
'SUPPORT': None,
'SVG': 'SVG',
'SVN': 'SUBVERSION',
'SWAGGER': 'SWAGGER',
'SWARM': None,
'SWIFT': None,
'SWING': None,
'SWITCHING': None,
'SYLIUS': 'SYLIUS',
'SYMFONY': 'SYMFONY',
'SYNTAX': None,
'SYPHONY': 'SYMFONY',
'SYSADMIN': 'SYSTEM',
'SYSTEM': 'SYSTEM',
'SYSTEMS': 'SYSTEM',
'SZYNA': None,
'TABELAU': None,
'TABLEAU': None,
'TAG': None,
'TCP': 'TCP',
'TDD': 'PROGRAMMING',
'TEAM': 'TEAMWORK',
'TEAMCITY': 'TEAMWORK',
'TEAMS': 'TEAMWORK',
'TEAMWORK': 'TEAMWORK',
'TECH': 'TECHNOLOGIES',
'TECHNICAL': 'TECHNOLOGIES',
'TECHNICZNA': 'TECHNOLOGIES',
'TECHNIQUES': 'TECHNOLOGIES',
'TECHNOLOGIES': 'TECHNOLOGIES',
'TECHNOLOGII': 'TECHNOLOGIES',
'TELEKOMUNIKACYJNE': None,
'TEMPLATES': None,
'TENSORFLOW': 'TENSORFLOW',
'TERADATA': 'TERADATA',
'TERRAFORM': 'TERRAFORM',
'TEST': 'TESTING',
'TESTER': 'TESTING',
'TESTFLIGHT': 'TESTING',
'TESTFLO': 'TESTING',
'TESTING': 'TESTING',
'TESTLINK': 'TESTING',
'TESTNG': 'TESTING',
'TESTOWANIE': 'TESTING',
'TESTRAIL': 'TESTING',
'TESTS': 'TESTING',
'TESTY': 'TESTING',
'TESTING' : None,
 'TESTLINK' : None,
 'TESTNG' : "TESTING",
 'TESTOWANIE' : None,
 'TESTRAIL' : None,
 'TESTS' : None,
 'TESTY' : "TESTS",
 'TESTÓW' : "TESTS",
 'TFS' : None,
 'THE': None,
 'THINKING' : None,
 'THREE' : None,
 'THRUK' : None,
 'TIME' : None,
 'TITLE' : None,
 'TLS': None,
 'TO': None,
 'TOMCAT': None,
 'TOOLS': None,
 'TOP': None,
 'TOUCH': None,
 'TRANSACT' : None,
 'TRANSFER' : None,
 'TRANSMISSION' : None,
 'TRIPS' : None,
 'TROUBLESHOOTING' : None,
 'TS' : None,
 'TWISTEAD' : "TWISTED",
 'TWISTED' : None,
 'TWITTER' : None,
 'TWORZENIE' : None,
 'TYPE' : None,
 'TYPESCRIPT' : None,
 'UART' : None,
 'UBUNTU' : None,
 'UC' : None,
 'UCD' : None,
 'UDP' : None,
 'UI': None,
 'UIKIT' : "UI",
 'UL': None,
 'UMBRACO' : None,
 'UMIEJĘTNOŚCI' : None,
 'UML' : None,
 'UNDER' : None,
 'UNDERSTANDING' : None,
 'UNIT' : None,
 'UNITS' : "UNIT",
 'UNITY' : None,
 'UNIX' : None,
 'UNNAMED' : None,
 'UNREAL' : None,
 'UP' : None,
 'USABILITY' : None,
 'USB' : None,
 'USER' : None,
 'UTRZYMANIE' : None,
 'UX' : None,
 'VB' : None,
 'VERSION' : None,
 'VISION' : None,
 'VISUAL' : None,
 'VISUALFORCE' : None,
 'VMS' : None,
 'VMWARE' : None,
 'VOIP' : None,
 'VUE' : None,
 'VUEJS': None,
 'VUEX' : None,
 'VULNERABILITY' : None,
 'WAREHOUSE' : None,
 'WAREHOUSING' : "WAREHOUSE",
 'WCAG' : None,
 'WCF' : None,
 'WDRAŻANIE' : None,
 'WEB' : None,
 'WEBAPI' : None,
 'WEBDRIVER' : None,
 'WEBFLUX' : None,
 'WEBGL' : None,
 'WEBLOGIC' : None,
 'WEBMETHODS' : None,
 'WEBPACK' : None,
 'WEBRTC' : None,
 'WEBSERVER' : None,
 'WEBSERVERS' : "WEBSERVER",
 'WEBSERVICE' : None,
 'WEBSERVICES' : "WEBSERVICE",
 'WEBSOCKET' : None,
 'WEBSOCKETS' : "WEBSOCKET",
 'WEBSPHERE' : None,
 'WEBTEST' : None,
 'WHICH' : None,
 'WIDZIANA' : None,
 'WILLINGNESS' : None,
 'WIN' : "WINDOWS",
 'WINDOWS' : None,
 'WINFORMS' : None,
 'WIREFRAMING' : None,
 'WITH' : None,
 'WM' : None,
 'WM<' : "VM",
 'WMI' : None,
 'WMS' : None,
 'WOOCOMMERCE' : None,
 'WORDPRESS' : None,
 'WORK' : None,
 'WORKED' : "WORK",
 'WORKING' : "WORK",
 'WPF' : None,
 'WRITER' : "WRITE",
 'WRITING' : "WRITE",
 'WRITTEN' : "WRITE",
 'WS' : None,
 'WSDL' : None,
 'WYKSZTAŁCENIE' : None,
 'WYŻSZE' : "WYKSZTAŁCENIE",
 'WZORCÓW' : None,
 'XAMARIN' : None,
 'XAML' : None,
 'XCODE' : None,
 'XCTEST' : None,
 'XD' : None,
 'XML' : None,
 'XP' : None,
 'XSD' : None,
 'XSLT' : None,
 'XSS' : None,
 'YAML' : None,
 'YARN' : None,
 'YEARS' : None,
 'ZABBIX' : None,
 'ZAGADNIEŃ' : None,
 'ZAPEWNIENIE' : None,
 'ZARZĄDZANIA' : "ZARZĄDZANIE",
 'ZARZĄDZANIE' : None,
 'ZEN' : None,
 'ZEND' : None,
 'ZEPLIN' : None,
 'ZNAJOMOŚĆ' : None,
         '>LE': 'LE',
    'A+': 'A+',
    'ABAP': 'ABAP',
    'ABILITY': None,
    'ACCEPTANCE': None,
    'ACCESS': 'ACCESS',
    'ACCOUNTING': None,
    'ACCOUNTS': None,
    'ACF': 'ACF',
    'ACTION': 'ACTION',
    'ACTIONSCRIPT': 'ACTIONSCRIPT',
    'ACTIVE': None,
    'AD': None,
    'ADB': 'ADB',
    'ADMINISTRATION': None,
    'ADMINISTRATOR': None,
    'ADOBE': 'ADOBE',
    'AGILE': 'AGILE',
    'AI': 'MACHINELEARNING',
    'AIRFLOW': 'AIRFLOW',
    'AIX': 'AIX',
    'AJAX': 'AJAX',
    'AKKA': 'AKKA',
    'ALCHEMY': 'ALCHEMY',
    'ALEXA': 'ALEXA',
    'ALGORITHM': None,
    'ALGORITHMIC': None,
    'ALGORITHMS': None,
    'AMAZON': 'AMAZON',
    'AMINISTRACJA': None,
    'AN': None,
    'ANALITICAL': 'ANALYTICAL',
    'ANALITYCZNE': 'ANALYTICAL',
    'ANALIZA': 'ANALYSIS',
    'ANALYSIS': 'ANALYSIS',
    'ANALYST': 'ANALYST',
    'ANALYTICAL': 'ANALYTICAL',
    'ANALYTICS': 'ANALYTICS',
    'ANALYZER': 'ANALYZER',
    'AND': None,
    'ANDROID': 'ANDROID',
    'ANGIELSKI': None,
    'ANGIELSKIEGO': None,
    'ANGULAR': 'ANGULAR',
    'ANGULARJS': 'ANGULARJS',
    'ANOTHER': None,
    'ANSIBLE': None,
    'ANT': 'ANT',
    'ANULAR': 'ANGULAR',
    'APACHE': 'APACHE',
    'APEX': 'APEX',
    'API': 'API',
    'APIS': 'API',
    'APP': None,
    'APPCODE': 'APPCODE',
    'APPIUM': 'APPIUM',
    'APPLESCRIPT': 'APPLESCRIPT',
    'APPLICATION': None,
    'APPLICATIONS': None,
    'APPROACHES': None,
    'APPS': None,
    'APPSTORE': None,
    'AR': 'MACHINE LEARNING',
    'ARCGIS': 'ARCGIS',
    'ARCHITECTURE': 'ARCHITECTURE',
    'ARCHITEKTURA': 'ARCHITECTURE',
    'ARCORE': 'ARCORE',
    'ARM': None,
    'ARTIFICIAL': 'MACHINELEARNING',
    'AS': None,
    'ASP': None,
    'ASPICE': None,
    'ASSERTIVENESS': None,
    'ASSETS': None,
    'ASSISTANT': None,
    'ASSURANCE': None,
    'ASVS': 'ASVS',
    'ASYNC': 'ASYNC',
    'ASYNCHRONOUS': None,
    'ASYNCIO': 'ASYNCIO',
    'AT': None,
    'ATTENTION': None,
    'ATTITUDE': None,
    'AUGMENTED': 'MACHINE LEARNING',
    'AUTO': None,
    'AUTOIT': 'AUTOIT',
    'AUTOMATED': None,
    'AUTOMATIC': 'AUTOMATION',
    'AUTOMATING': 'AUTOMATION',
    'AUTOMATION': 'AUTOMATION',
    'AUTOMATYCZNYCH': 'AUTOMATION',
    'AUTOMATYZACJA': 'AUTOMATION',
    'AUTOSAR': 'AUTOSAR',
    'AVAILABILITY': None,
    'AWS': 'AWS',
    'AX': None,
    'AXURE': 'AZURE',
    'AYTOLAYOUT': None,
    'AZURE': 'AZURE',
    'AZUREDEVOPS': 'AZURE',
    'BABEL': 'BABEL',
    'BACHELOR': None,
    'BACK': None,
    'BACKEND': 'BACKEND',
    'BACKGROUD': None,
    'BACKLOG': 'BACKLOG',
    'BACKUP': None,
    'BASH': 'BASH',
    'BASIC': None,
    'BATCH': 'BATCH',
    'BAZ': 'BAZ',
    'BAZAMI': 'BAZAMI',
    'BAZY': None,
    'BCP': 'BCP',
    'BDD': 'BDD',
    'BI': 'BI',
    'BIAS': 'BIAS',
    'BIG': None,
    'BIGDATA': 'BIGDATA',
    'BITBUCKET': 'BITBUCKET',
    'BIZNESOWA': None,
    'BLADE': 'BLADE',
    'BLOCKCHAIN': 'BLOCKCHAIN',
    'BLUETOOTH': None,
    'BOL': None,
    'BOOST': 'BOOST',
    'BOOT': None,
    'BOOTSTRAP': 'BOOTSTRAP',
    'BPM': None,
    'BPMN': None,
    'BPMP': None,
    'BROWSER': None,
    'BUG': None,
    'BUILDER': 'BUILDER',
    'BURP': None,
    'BUSINESS': None,
    'BUTTERKNIFE': 'BUTTERKNIFE',
    'BW': 'BW',
    'C#': 'C#',
    'C++': 'C++',
    'CAFFE': 'CAFFE'
}

# %%
skills = list(sorted(set(filter(lambda x: x is not None, dict6.values()))))

# %%
max(np.nan,2)
# Out:
# nan

# %%
max(2,np.nan)
# Out:
# 2

# %%
df_offers['C++'].count()
# Out:
# 16

# %%
df_offers['Java'].count()
# Out:
# 116

# %%
df_offers['Python'].count()
# Out:
# 95

# %%
dict7 = {}
for k, v in dict6.items():
    k_escaped = k.replace("+", "\+")
    dict7[k_escaped] = v
    
skills = list(sorted(set(filter(lambda x: x is not None, dict7.values()))))

# %%
df_info = df_offers[["company", "emp_type", "exp_lvl", "title", "salary_min", "salary_max", "city"]]
unified_df = df_info.copy()
for skill, target_skill in dict7.items():
    if target_skill is not None:
        try:
            col = unified_df[target_skill]
            temp = pd.DataFrame()
            temp['temp'] = df_offers.filter(regex=re.compile(rf"(skill)\b", re.I)).max(axis=1)
            temp[target_skill] = unified_df[target_skill]
            unified_df[target_skill] = temp[['temp', target_skill]].max(axis=1)

        except Exception:
            unified_df[target_skill] = df_offers.filter(regex=re.compile(rf"(skill)\b", re.I)).max(axis=1)

        
# bierzmy max bo jeśli bedzie w jednej kolumnie np. angular2 -> wartosc 2 i 
# angurar3 -> wartosc 4, to bierzemy max dla nowej kolumny angular czyli wartosc 4

# %%
import math
sum(1 for x in list(unified_df["C++"]) if not math.isnan(float(x)))
# Out:
# 0

# %%
unified_df['C++'].count()
# Out:
# 31

# %%
unified_df['JAVASCRIPT'].count()
# Out:
# 688

# %%
unified_df.head(2)
# Out:
#                company   emp_type  exp_lvl  \
# 0  GTS Tech Sp. z o.o.  Permanent        3
# 1         Mindbox S.A.        B2B        2
#
#                                       title  salary_min  salary_max    city  \
# 0  Senior Full-Stack Developer- Team Leader      6300.0     11200.0  Kraków
# 1                    QA Automation Engineer     12000.0     20000.0  Kraków
#
#    C#  ACF  ADMINISTRACJA  ADOBE  ADWORDS  AGILE  MACHINELEARNING  AIRFLOW  \
# 0 NaN  NaN            NaN    NaN      NaN    NaN              NaN      NaN
# 1 NaN  NaN            NaN    NaN      NaN    NaN              NaN      NaN
#
#    AKKA  AMAZON  ACTIVEMQ  ANALYTICAL  ANALYSIS  ANALYST  ANALYTICS  ANALYZER  \
# 0   NaN     NaN       NaN         NaN       NaN      NaN        NaN       NaN
# 1   NaN     NaN       NaN         NaN       NaN      NaN        NaN       NaN
#
#    ANDROID  ANGULAR  ANGULARJS  ANT  APACHE  APEX  API  APPCODE  APPIUM  \
# ...

# %%
test_offer = unified_df[unified_df['title'] == 'QA Automation Engineer'].iloc[1, :]
test_offer[test_offer.notnull() == True]
# teraz nie ma kolumny 'NaN', bo dodaliśmy if target_skill is not none
# Out:
# company                       Mindbox S.A.
# emp_type                               B2B
# exp_lvl                                  2
# title               QA Automation Engineer
# salary_min                           11000
# salary_max                           14000
# city                              Warszawa
# MACHINE LEARNING                     14000
# REST                                     1
# JAVA                                     4
# JAVASCRIPT                               1
# JENKINS                                  4
# JMETER                                   5
# MAVEN                                    4
# GIT                                      4
# SEO                                      5
# SELENIUM                                 5
# WEB                                      5
# Name: 5, dtype: object

# %%
unified_df.head(2)
# Out:
#                company   emp_type  exp_lvl  \
# 0  GTS Tech Sp. z o.o.  Permanent        3
# 1         Mindbox S.A.        B2B        2
#
#                                       title  salary_min  salary_max    city  \
# 0  Senior Full-Stack Developer- Team Leader      6300.0     11200.0  Kraków
# 1                    QA Automation Engineer     12000.0     20000.0  Kraków
#
#    C#  ACF  ADMINISTRACJA  ADOBE  ADWORDS  AGILE  MACHINELEARNING  AIRFLOW  \
# 0 NaN  NaN            NaN    NaN      NaN    NaN              NaN      NaN
# 1 NaN  NaN            NaN    NaN      NaN    NaN              NaN      NaN
#
#    AKKA  AMAZON  ACTIVEMQ  ANALYTICAL  ANALYSIS  ANALYST  ANALYTICS  ANALYZER  \
# 0   NaN     NaN       NaN         NaN       NaN      NaN        NaN       NaN
# 1   NaN     NaN       NaN         NaN       NaN      NaN        NaN       NaN
#
#    ANDROID  ANGULAR  ANGULARJS  ANT  APACHE  APEX  API  APPCODE  APPIUM  \
# ...

# %%
# uwaga! exp_lvl mamy w skali 1-3, a skille w skali 1-5, trzeba te dane znormalizować
# naszą zmienną celu y będzie salary_min, albo salary_max
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import model_selection
import sklearn.linear_model as lm
import xgboost as xgb
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn import  metrics
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
y = unified_df["salary_max"]
X = unified_df.drop(["salary_min", "salary_max", "company", "emp_type", "title", "city"], axis=1)

# %%
X.head(1)
# Out:
#    exp_lvl  C#  ACF  ADMINISTRACJA  ADOBE  ADWORDS  AGILE  MACHINELEARNING  \
# 0        3 NaN  NaN            NaN    NaN      NaN    NaN              NaN
#
#    AIRFLOW  AKKA  AMAZON  ACTIVEMQ  ANALYTICAL  ANALYSIS  ANALYST  ANALYTICS  \
# 0      NaN   NaN     NaN       NaN         NaN       NaN      NaN        NaN
#
#    ANALYZER  ANDROID  ANGULAR  ANGULARJS  ANT  APACHE  APEX  API  APPCODE  \
# 0       NaN      NaN      NaN        NaN  NaN     NaN   NaN  NaN      NaN
#
#    APPIUM  MACHINE LEARNING  ARCHITECTURE  ARTIFACTORY  ASYNC  AUTOMATION  \
# 0     NaN               NaN           NaN          NaN    NaN         NaN
#
#    AUTOSAR  PROJECTMANAGER  POLISH  POSIX  POSTGRESQL  POSTMAN  POWERSHELL  \
# 0      NaN             NaN     NaN    NaN         NaN      NaN         NaN
#
#    PRESTASHOP  PRIMEFACES  PROMETHEUS  PROMISE  PROTOTYPEJS  PROTRACTOR  \
# 0         NaN         NaN         NaN      NaN          NaN         NaN
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
kfold = model_selection.KFold(n_splits=5, random_state=42)

# xgb_r = xgb.XGBRegressor(colsample_bytree=0.4, gamma=0, min_child_weight=1.5, reg_alpha=0.75, reg_lambda=0.45, subsample=0.6,
#                  seed=42)
xgb_r = xgb.XGBRegressor(
   max_depth=5,
    learning_rate=0.07,
    n_estimators=1000,
    seed=42,
    n_jobs=-1,
    colsample_bytree=0.6
)

# %%
xgb_r.fit(X_train, y_train)


print(f"R^2 train: {r2_score(y_true=y_train, y_pred=xgb_r.predict(X_train))}")
print(f"R^2 test: {r2_score(y_true=y_test, y_pred=xgb_r.predict(X_test))}")
print(f"MAE train: {mean_absolute_error(y_true=y_train, y_pred=xgb_r.predict(X_train))}")
print(f"MAE test: {mean_absolute_error(y_true=y_test, y_pred=xgb_r.predict(X_test))}")


print(unified_df["salary_max"].max())
print(unified_df["salary_min"].min())
# Out:
# R^2 train: 0.3378655594748675
# R^2 test: 0.3387032775311416
# MAE train: 3177.572314179578
# MAE test: 3122.329179496641
# 33000.0
# 600.0

# %%
X_train.head(1)
# Out:
#      exp_lvl  C#  ACF  ADMINISTRACJA  ADOBE  ADWORDS  AGILE  MACHINELEARNING  \
# 227        2 NaN  NaN            NaN    NaN      NaN    NaN              NaN
#
#      AIRFLOW  AKKA  AMAZON  ACTIVEMQ  ANALYTICAL  ANALYSIS  ANALYST  \
# 227      NaN   NaN     NaN       NaN         NaN       NaN      NaN
#
#      ANALYTICS  ANALYZER  ANDROID  ANGULAR  ANGULARJS  ANT  APACHE  APEX  API  \
# 227        NaN       NaN      NaN      NaN        NaN  NaN     NaN   NaN  NaN
#
#      APPCODE  APPIUM  MACHINE LEARNING  ARCHITECTURE  ARTIFACTORY  ASYNC  \
# 227      NaN     NaN            8400.0           NaN          NaN    NaN
#
#      AUTOMATION  AUTOSAR  PROJECTMANAGER  POLISH  POSIX  POSTGRESQL  POSTMAN  \
# 227         NaN      NaN             NaN     NaN    NaN         NaN      NaN
#
#      POWERSHELL  PRESTASHOP  PRIMEFACES  PROMETHEUS  PROMISE  PROTOTYPEJS  \
# 227         NaN         NaN         NaN         NaN      NaN          NaN
#
# ...

# %%
X_train.columns
X_train[X_train.notnull() == True]
# Out:
#       exp_lvl   C#  ACF  ADMINISTRACJA  ADOBE  ADWORDS  AGILE  \
# 227         2  NaN  NaN            NaN    NaN      NaN    NaN
# 873         2  NaN  NaN            NaN    NaN      NaN    NaN
# 359         3  NaN  NaN            NaN    NaN      NaN    NaN
# 813         1  NaN  NaN            NaN    NaN      NaN    NaN
# 177         3  NaN  NaN            NaN    NaN      NaN    NaN
# 995         3  NaN  NaN            NaN    NaN      NaN    NaN
# 756         2  NaN  NaN            NaN    NaN      NaN    NaN
# 493         3  NaN  NaN            NaN    NaN      NaN    NaN
# 334         2  3.0  NaN            NaN    NaN      NaN    NaN
# 892         2  NaN  NaN            NaN    NaN      NaN    NaN
# 7           3  NaN  NaN            NaN    NaN      NaN    NaN
# 155         2  NaN  NaN            NaN    NaN      NaN    NaN
# 842         2  NaN  NaN            NaN    NaN      NaN    NaN
# 750         1  4.0  NaN            NaN    NaN      NaN    NaN
# ...

# %%
t = X.iloc[1, :]
t[t.notnull() == True]
# Out:
# exp_lvl                 2.0
# MACHINE LEARNING    20000.0
# REST                    1.0
# JAVA                    4.0
# JAVASCRIPT              1.0
# JENKINS                 4.0
# JMETER                  5.0
# MAVEN                   4.0
# GIT                     4.0
# SEO                     5.0
# SELENIUM                5.0
# WEB                     5.0
# Name: 1, dtype: float64
